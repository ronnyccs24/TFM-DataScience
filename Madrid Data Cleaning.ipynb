# %% [markdown]
# <img src="./airbnb.png" height="96" width="96">
# <br />
# <div style="text-align: center;">
#     <span style="font-weight: bold; color:#FF7674; font-family: 'Courier New'; font-size: 5em;">Madrid Data Cleaning</span>
# </div>
#
# <br />
# <div style="text-align: left;">
#     <span style="color:#8585BB; font-family: 'Courier New'; font-size: 1.5em;">En las siguientes líneas de código estaremos haciendo una limpieza y exploración de los datos obtenidos de www.insideairbnb.com para la ciudad de Madrid.</span>
# </div>

# %%
import sys
import pandas as pd                   
import datetime as dt                  
import numpy as np                    
import re

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print('Python version: ', sys.version)
print('Pandas version: ', pd.__version__)
print('Today: ', dt.date.today())
# Out:
# ('Python version: ', '2.7.12 |Anaconda custom (64-bit)| (default, Jun 29 2016, 11:07:13) [MSC v.1500 64 bit (AMD64)]')
# ('Pandas version: ', u'0.18.1')
# ('Today: ', datetime.date(2017, 7, 14))

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Vamos a echar un vistazo a nuestros datasets obtenidos de www.insideairbnb.com<br>
# La data obtenida es del 08 de abril de 2017</span>
# </div>

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Según Insideairbnb.com, la siguiente tabla es: *Detailed Listings data for Madrid*</span>
# </div>

# %%
listing = pd.read_csv('./listings_1.csv', sep=',')
print 'Dimensión:', listing.shape
listing.tail(3)
# Out:
# Dimensión: (13335, 95)
#              id                            listing_url       scrape_id  \
# 13332  16392617  https://www.airbnb.com/rooms/16392617  20170407214119
# 13333  17840364  https://www.airbnb.com/rooms/17840364  20170407214119
# 13334  17829874  https://www.airbnb.com/rooms/17829874  20170407214119
#
#       last_scraped                                             name  \
# 13332   2017-04-08  Piso con Terraza 2 personas, Aceptamos Mascotas
# 13333   2017-04-08                              Apartamento pozuelo
# 13334   2017-04-08                      HABITACIÓN CON BAÑO PRIVADO
#
#                                                  summary  \
# 13332  Piso acogedor, habitación individual para los ...
# 13333  Apartamento   tranquilo muy cerca de Madrid ca...
# 13334  Habitación con baño privado. Zona verde y tran...
#
#                                                    space  \
# 13332  Hola! Somos dos hermanas jóvenes y compartimos...
# 13333                                                NaN
# 13334                                                NaN
#
#                                              description experiences_offered  \
# 13332  Piso acogedor, habitación individual para los ...                none
# 13333  Apartamento   tranquilo muy cerca de Madrid ca...                none
# 13334  Habitación con baño privado. Zona verde y tran...                none
#
#                                    neighborhood_overview notes transit  \
# 13332  Está justo al lado del metro Jarama y autobuse...   NaN     NaN
# 13333                                                NaN   NaN     NaN
# 13334                                                NaN   NaN     NaN
#
#                                                   access  \
# 13332  Baño compartido recién reformado en color pist...
# 13333                                                NaN
# 13334  Habitación con baño . Zonas de acceso a la mis...
#
#                                              interaction  \
# 13332  Pueden encontrarme en casa fuera de mi horario...
# 13333                                                NaN
# 13334                                 Poca conversación.
#
#                                              house_rules  \
# 13332  - Hora de entrada y salida Flexible previo avi...
# 13333   El precio  incluye  limpieza   De el apartamento
# 13334  - No dar mucha conversación ni invadir espacio...
#
#                                            thumbnail_url  \
# 13332  https://a0.muscache.com/im/pictures/c9c35abc-f...
# 13333  https://a0.muscache.com/im/pictures/1ec37eca-a...
# 13334  https://a0.muscache.com/im/pictures/884f1919-7...
#
#                                               medium_url  \
# 13332  https://a0.muscache.com/im/pictures/c9c35abc-f...
# 13333  https://a0.muscache.com/im/pictures/1ec37eca-a...
# 13334  https://a0.muscache.com/im/pictures/884f1919-7...
#
#                                              picture_url  \
# 13332  https://a0.muscache.com/im/pictures/c9c35abc-f...
# 13333  https://a0.muscache.com/im/pictures/1ec37eca-a...
# 13334  https://a0.muscache.com/im/pictures/884f1919-7...
#
#                                           xl_picture_url    host_id  \
# 13332  https://a0.muscache.com/im/pictures/c9c35abc-f...   17961354
# 13333  https://a0.muscache.com/im/pictures/1ec37eca-a...  107332075
# 13334  https://a0.muscache.com/im/pictures/884f1919-7...  121929599
#
#                                           host_url host_name  host_since  \
# 13332   https://www.airbnb.com/users/show/17961354     Laila  2014-07-11
# 13333  https://www.airbnb.com/users/show/107332075     Chely  2016-12-15
# 13334  https://www.airbnb.com/users/show/121929599       Agm  2017-03-21
#
#                             host_location host_about host_response_time  \
# 13332  Madrid, Community of Madrid, Spain        NaN       within a day
# 13333                                  ES        NaN     within an hour
# 13334                                  ES        NaN     within an hour
#
#       host_response_rate  host_acceptance_rate host_is_superhost  \
# 13332                50%                   NaN                 f
# 13333               100%                   NaN                 f
# 13334               100%                   NaN                 f
#
#                                       host_thumbnail_url  \
# 13332  https://a0.muscache.com/im/users/17961354/prof...
# 13333  https://a0.muscache.com/im/pictures/22e2e3b6-6...
# 13334  https://a0.muscache.com/im/pictures/7fcc5040-c...
#
#                                         host_picture_url host_neighbourhood  \
# 13332  https://a0.muscache.com/im/users/17961354/prof...                NaN
# 13333  https://a0.muscache.com/im/pictures/22e2e3b6-6...            Adelfas
# 13334  https://a0.muscache.com/im/pictures/7fcc5040-c...                NaN
#
#        host_listings_count  host_total_listings_count  \
# 13332                  2.0                        2.0
# 13333                  3.0                        3.0
# 13334                  1.0                        1.0
#
#                                       host_verifications host_has_profile_pic  \
# 13332  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 13333                      ['email', 'phone', 'reviews']                    t
# 13334                                 ['email', 'phone']                    t
#
#       host_identity_verified  \
# 13332                      t
# 13333                      f
# 13334                      f
#
#                                                   street neighbourhood  \
# 13332  San Fernando de Henares, Comunidad de Madrid 2...           NaN
# 13333  Pozuelo de Alarcón, Comunidad de Madrid 28224,...           NaN
# 13334  San Fernando de Henares, Comunidad de Madrid 2...           NaN
#
#              neighbourhood_cleansed neighbourhood_group_cleansed  \
# 13332  Casco Histórico de Vicálvaro                    Vicálvaro
# 13333                    El Plantío            Moncloa - Aravaca
# 13334  Casco Histórico de Vicálvaro                    Vicálvaro
#
#                           city                state zipcode  market  \
# 13332  San Fernando de Henares  Comunidad de Madrid   28830  Madrid
# 13333       Pozuelo de Alarcón  Comunidad de Madrid   28224  Madrid
# 13334  San Fernando de Henares  Comunidad de Madrid   28830  Madrid
#
#                        smart_location country_code country   latitude  \
# 13332  San Fernando de Henares, Spain           ES   Spain  40.422470
# 13333       Pozuelo de Alarcón, Spain           ES   Spain  40.459903
# 13334  San Fernando de Henares, Spain           ES   Spain  40.422271
#
#        longitude is_location_exact property_type        room_type  \
# 13332  -3.526821                 f     Apartment     Private room
# 13333  -3.801603                 f     Apartment  Entire home/apt
# 13334  -3.531159                 f         House     Private room
#
#        accommodates  bathrooms  bedrooms  beds  bed_type  \
# 13332             2        1.0       1.0   2.0  Real Bed
# 13333             2        1.0       1.0   1.0  Real Bed
# 13334             1        1.0       1.0   1.0  Real Bed
#
#                                                amenities  square_feet   price  \
# 13332  {TV,Internet,"Wireless Internet",Kitchen,"Pets...          NaN  $25.00
# 13333  {TV,Internet,"Wireless Internet",Pool,Kitchen,...          NaN  $45.00
# 13334  {"Wireless Internet","Pets allowed",Heating,Es...          NaN  $15.00
#
#       weekly_price monthly_price security_deposit cleaning_fee  \
# 13332          NaN           NaN          $100.00        $5.00
# 13333          NaN           NaN              NaN          NaN
# 13334          NaN           NaN              NaN          NaN
#
#        guests_included extra_people  minimum_nights  maximum_nights  \
# 13332                1        $0.00               1            1125
# 13333                1       $15.00               2            1125
# 13334                1        $0.00               1              90
#
#       calendar_updated  has_availability  availability_30  availability_60  \
# 13332       a week ago               NaN               26               56
# 13333       5 days ago               NaN               11               32
# 13334       4 days ago               NaN               15               45
#
#        availability_90  availability_365 calendar_last_scraped  \
# 13332               86               361            2017-04-07
# 13333               62               337            2017-04-08
# 13334               75               350            2017-04-08
#
#        number_of_reviews first_review last_review  review_scores_rating  \
# 13332                  0          NaN         NaN                   NaN
# 13333                  1   2017-03-26  2017-03-26                 100.0
# 13334                  0          NaN         NaN                   NaN
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 13332                     NaN                        NaN
# 13333                    10.0                       10.0
# 13334                     NaN                        NaN
#
#        review_scores_checkin  review_scores_communication  \
# 13332                    NaN                          NaN
# 13333                   10.0                         10.0
# 13334                    NaN                          NaN
#
#        review_scores_location  review_scores_value requires_license license  \
# 13332                     NaN                  NaN                t     NaN
# 13333                     8.0                 10.0                t     NaN
# 13334                     NaN                  NaN                t     NaN
#
#        jurisdiction_names instant_bookable cancellation_policy  \
# 13332                 NaN                f            flexible
# 13333                 NaN                f            flexible
# 13334                 NaN                f              strict
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 13332                             f                                f
# 13333                             f                                f
# 13334                             f                                f
#
#        calculated_host_listings_count  reviews_per_month
# 13332                               1                NaN
# 13333                               3                1.0
# 13334                               1                NaN

# %%
listing.columns
# Out:
# Index([u'id', u'listing_url', u'scrape_id', u'last_scraped', u'name',
#        u'summary', u'space', u'description', u'experiences_offered',
#        u'neighborhood_overview', u'notes', u'transit', u'access',
#        u'interaction', u'house_rules', u'thumbnail_url', u'medium_url',
#        u'picture_url', u'xl_picture_url', u'host_id', u'host_url',
#        u'host_name', u'host_since', u'host_location', u'host_about',
#        u'host_response_time', u'host_response_rate', u'host_acceptance_rate',
#        u'host_is_superhost', u'host_thumbnail_url', u'host_picture_url',
#        u'host_neighbourhood', u'host_listings_count',
#        u'host_total_listings_count', u'host_verifications',
#        u'host_has_profile_pic', u'host_identity_verified', u'street',
#        u'neighbourhood', u'neighbourhood_cleansed',
#        u'neighbourhood_group_cleansed', u'city', u'state', u'zipcode',
#        u'market', u'smart_location', u'country_code', u'country', u'latitude',
#        u'longitude', u'is_location_exact', u'property_type', u'room_type',
#        u'accommodates', u'bathrooms', u'bedrooms', u'beds', u'bed_type',
#        u'amenities', u'square_feet', u'price', u'weekly_price',
#        u'monthly_price', u'security_deposit', u'cleaning_fee',
#        u'guests_included', u'extra_people', u'minimum_nights',
#        u'maximum_nights', u'calendar_updated', u'has_availability',
#        u'availability_30', u'availability_60', u'availability_90',
#        u'availability_365', u'calendar_last_scraped', u'number_of_reviews',
#        u'first_review', u'last_review', u'review_scores_rating',
#        u'review_scores_accuracy', u'review_scores_cleanliness',
#        u'review_scores_checkin', u'review_scores_communication',
#        u'review_scores_location', u'review_scores_value', u'requires_license',
#        u'license', u'jurisdiction_names', u'instant_bookable',
#        u'cancellation_policy', u'require_guest_profile_picture',
#        u'require_guest_phone_verification', u'calculated_host_listings_count',
#        u'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Según www.insideairbnb.com, la siguiente tabla es: *Summary information and metrics for listings in Madrid (good for visualisations)*.</span>
# </div>

# %%
listing_sum = pd.read_csv('./listings.csv', sep=',')
print 'Dimensión:', listing_sum.shape
listing_sum.head(3)
# Out:
# Dimensión: (13335, 16)
#          id                                         name   host_id  \
# 0   7830063                    Quiet room in Plaza Mayor  41032693
# 1   9898596      Homely apartment in the heart of Madrid  50908516
# 2  15334645  Piso Muy Luminoso en pleno centro de Madrid  97753616
#
#      host_name neighbourhood_group neighbourhood   latitude  longitude  \
# 0  Bluekitchen              Centro       Palacio  40.412275  -3.708718
# 1       Daniel              Centro       Palacio  40.411093  -3.708985
# 2         Will              Centro       Palacio  40.413587  -3.708945
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     42               2                100  2017-04-02
# 1  Entire home/apt    135               1                 68  2017-04-04
# 2  Entire home/apt     81               1                 34  2017-03-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               5.04                               7               165
# 1               4.39                               1               230
# 2               5.57                               1               287

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Según Insideairbnb.com, la siguiente tabla es: *Detailed Calendar Data for listings in Madrid*.</span>
# </div>

# %%
calendar = pd.read_csv('./calendar.csv', sep=',')
calendar.tail(3)
# Out:
#          listing_id        date available   price
# 4867272    17829874  2017-04-10         t  $15.00
# 4867273    17829874  2017-04-09         t  $15.00
# 4867274    17829874  2017-04-08         f     NaN

# %%
#Según Insideairbnb.com, la siguiente tabla es: Detailed Review Data for listings in Madrid
review_sum = pd.read_csv('./reviews_1.csv')
review_sum.head(3)
# Out:
#    listing_id        date
# 0    15128601  2016-09-25
# 1    15128601  2016-10-03
# 2    15128601  2016-10-07

# %%
#Según Insideairbnb.com, la siguiente tabla es: Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).
review = pd.read_csv('./reviews.csv')
review.head(3)
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0    15128601  103956852  2016-09-25     48832799        Amparo
# 1    15128601  105883025  2016-10-03     87158075       Daniela
# 2    15128601  106595943  2016-10-07     10102108        Fabien
#
#                                             comments
# 0  Apartamento muy acogedor, limpio y cómodo, en ...
# 1  La descripción del anuncio era correcta, las f...
# 2  Nice and cosy place. Really peaceful and quiet...

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Una vez vistos los datos que podemos obtener de Inside Airbnb, vamos a descartar las tablas resumidas y usar las tablas que tienen mayor cantidad de datos para poder moldearlas a nuestro gusto.<br><br></span>
# </div>
#
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Las tablas que finalmente utilizaremos serán:<br><br>
# - listing = pd.read_csv('./listings_1.csv', sep=',')<br>
# - calendar = pd.read_csv('./calendar.csv', sep=',')<br>
# - review = pd.read_csv('./reviews.csv')</span>
# </div>

# %% [markdown]
# <br><div style="text-align: left;">
#     <span style="font-weight: bold; color:#FF7674; font-family: 'Courier New'; font-size: 2em;">Data Cleaning</span>
# </div>
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Aunque los datos reales nunca están limpios completamente, necesitamos asegurarnos de limpiarlos lo mayor posible convirtiendo o eliminando valores nulos o faltantes.<br><br></span>
# </div>

# %%
listing.describe().transpose()
# Out:
# C:\Users\ronny\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                                   count          mean           std  \
# id                              13335.0  1.043929e+07  5.517349e+06
# scrape_id                       13335.0  2.017041e+13  4.890808e+00
# host_id                         13335.0  3.775842e+07  3.470057e+07
# host_acceptance_rate                0.0           NaN           NaN
# host_listings_count             13332.0  9.777453e+00  2.781298e+01
# host_total_listings_count       13332.0  9.777453e+00  2.781298e+01
# latitude                        13335.0  4.042073e+01  2.034312e-02
# longitude                       13335.0 -3.697255e+00  2.383740e-02
# accommodates                    13335.0  3.184252e+00  1.990534e+00
# bathrooms                       13285.0  1.251675e+00  5.981173e-01
# bedrooms                        13312.0  1.293495e+00  8.247503e-01
# beds                            13286.0  1.981936e+00  1.511608e+00
# square_feet                       522.0  3.758352e+02  5.459670e+02
# guests_included                 13335.0  1.572628e+00  1.088805e+00
# minimum_nights                  13335.0  3.009824e+00  1.282894e+01
# maximum_nights                  13335.0  9.597532e+02  8.883119e+03
# has_availability                    0.0           NaN           NaN
# availability_30                 13335.0  8.831496e+00  9.152567e+00
# availability_60                 13335.0  2.307762e+01  1.958616e+01
# availability_90                 13335.0  4.030664e+01  2.942652e+01
# availability_365                13335.0  2.058828e+02  1.269678e+02
# number_of_reviews               13335.0  2.298755e+01  3.839320e+01
# review_scores_rating            10417.0  9.162062e+01  8.983817e+00
# review_scores_accuracy          10399.0  9.408020e+00  9.244271e-01
# review_scores_cleanliness       10405.0  9.326382e+00  9.949704e-01
# review_scores_checkin           10389.0  9.622293e+00  7.916267e-01
# review_scores_communication     10405.0  9.644786e+00  7.575793e-01
# review_scores_location          10387.0  9.542794e+00  7.666081e-01
# review_scores_value             10387.0  9.212573e+00  9.541097e-01
# jurisdiction_names                  0.0           NaN           NaN
# calculated_host_listings_count  13335.0  7.600075e+00  1.961052e+01
# reviews_per_month               10542.0  1.923220e+00  1.888180e+00
#
#                                          min           25%           50%  \
# id                              1.862800e+04  5.858327e+06  1.157754e+07
# scrape_id                       2.017041e+13  2.017041e+13  2.017041e+13
# host_id                         1.745300e+04  7.823688e+06  2.752699e+07
# host_acceptance_rate                     NaN           NaN           NaN
# host_listings_count             0.000000e+00           NaN           NaN
# host_total_listings_count       0.000000e+00           NaN           NaN
# latitude                        4.033189e+01  4.041009e+01  4.041872e+01
# longitude                      -3.863907e+00 -3.707852e+00 -3.701596e+00
# accommodates                    1.000000e+00  2.000000e+00  2.000000e+00
# bathrooms                       0.000000e+00           NaN           NaN
# bedrooms                        0.000000e+00           NaN           NaN
# beds                            1.000000e+00           NaN           NaN
# square_feet                     0.000000e+00           NaN           NaN
# guests_included                 1.000000e+00  1.000000e+00  1.000000e+00
# minimum_nights                  1.000000e+00  1.000000e+00  2.000000e+00
# maximum_nights                  1.000000e+00  3.650000e+02  1.125000e+03
# has_availability                         NaN           NaN           NaN
# availability_30                 0.000000e+00  0.000000e+00  6.000000e+00
# availability_60                 0.000000e+00  5.000000e+00  2.000000e+01
# availability_90                 0.000000e+00  1.300000e+01  3.800000e+01
# availability_365                0.000000e+00  8.400000e+01  2.470000e+02
# number_of_reviews               0.000000e+00  1.000000e+00  7.000000e+00
# review_scores_rating            2.000000e+01           NaN           NaN
# review_scores_accuracy          2.000000e+00           NaN           NaN
# review_scores_cleanliness       2.000000e+00           NaN           NaN
# review_scores_checkin           2.000000e+00           NaN           NaN
# review_scores_communication     2.000000e+00           NaN           NaN
# review_scores_location          2.000000e+00           NaN           NaN
# review_scores_value             2.000000e+00           NaN           NaN
# jurisdiction_names                       NaN           NaN           NaN
# calculated_host_listings_count  1.000000e+00  1.000000e+00  2.000000e+00
# reviews_per_month               2.000000e-02           NaN           NaN
#
#                                          75%           max
# id                              1.538489e+07  1.810984e+07
# scrape_id                       2.017041e+13  2.017041e+13
# host_id                         5.799251e+07  1.247534e+08
# host_acceptance_rate                     NaN           NaN
# host_listings_count                      NaN  5.190000e+02
# host_total_listings_count                NaN  5.190000e+02
# latitude                        4.042800e+01  4.056274e+01
# longitude                      -3.693810e+00 -3.526821e+00
# accommodates                    4.000000e+00  1.600000e+01
# bathrooms                                NaN  8.000000e+00
# bedrooms                                 NaN  1.000000e+01
# beds                                     NaN  1.600000e+01
# square_feet                              NaN  5.167000e+03
# guests_included                 2.000000e+00  1.600000e+01
# minimum_nights                  3.000000e+00  1.125000e+03
# maximum_nights                  1.125000e+03  1.000000e+06
# has_availability                         NaN           NaN
# availability_30                 1.400000e+01  3.000000e+01
# availability_60                 3.800000e+01  6.000000e+01
# availability_90                 6.500000e+01  9.000000e+01
# availability_365                3.210000e+02  3.650000e+02
# number_of_reviews               2.800000e+01  4.460000e+02
# review_scores_rating                     NaN  1.000000e+02
# review_scores_accuracy                   NaN  1.000000e+01
# review_scores_cleanliness                NaN  1.000000e+01
# review_scores_checkin                    NaN  1.000000e+01
# review_scores_communication              NaN  1.000000e+01
# review_scores_location                   NaN  1.000000e+01
# review_scores_value                      NaN  1.000000e+01
# jurisdiction_names                       NaN           NaN
# calculated_host_listings_count  4.000000e+00  1.450000e+02
# reviews_per_month                        NaN  1.721000e+01

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13335 entries, 0 to 13334
# Data columns (total 95 columns):
# id                                  13335 non-null int64
# listing_url                         13335 non-null object
# scrape_id                           13335 non-null int64
# last_scraped                        13335 non-null object
# name                                13335 non-null object
# summary                             12846 non-null object
# space                               9700 non-null object
# description                         13329 non-null object
# experiences_offered                 13335 non-null object
# neighborhood_overview               8308 non-null object
# notes                               5037 non-null object
# transit                             8264 non-null object
# access                              7546 non-null object
# interaction                         7523 non-null object
# house_rules                         8666 non-null object
# thumbnail_url                       10847 non-null object
# medium_url                          10847 non-null object
# picture_url                         13335 non-null object
# xl_picture_url                      10847 non-null object
# host_id                             13335 non-null int64
# host_url                            13335 non-null object
# host_name                           13332 non-null object
# host_since                          13332 non-null object
# host_location                       13293 non-null object
# host_about                          8282 non-null object
# host_response_time                  11622 non-null object
# host_response_rate                  11622 non-null object
# host_acceptance_rate                0 non-null float64
# host_is_superhost                   13332 non-null object
# host_thumbnail_url                  13332 non-null object
# host_picture_url                    13332 non-null object
# host_neighbourhood                  9983 non-null object
# host_listings_count                 13332 non-null float64
# host_total_listings_count           13332 non-null float64
# host_verifications                  13335 non-null object
# host_has_profile_pic                13332 non-null object
# host_identity_verified              13332 non-null object
# street                              13335 non-null object
# neighbourhood                       8772 non-null object
# neighbourhood_cleansed              13335 non-null object
# neighbourhood_group_cleansed        13335 non-null object
# city                                13333 non-null object
# state                               13292 non-null object
# zipcode                             12896 non-null object
# market                              13285 non-null object
# smart_location                      13335 non-null object
# country_code                        13335 non-null object
# country                             13334 non-null object
# latitude                            13335 non-null float64
# longitude                           13335 non-null float64
# is_location_exact                   13335 non-null object
# property_type                       13335 non-null object
# room_type                           13335 non-null object
# accommodates                        13335 non-null int64
# bathrooms                           13285 non-null float64
# bedrooms                            13312 non-null float64
# beds                                13286 non-null float64
# bed_type                            13335 non-null object
# amenities                           13335 non-null object
# square_feet                         522 non-null float64
# price                               13335 non-null object
# weekly_price                        3512 non-null object
# monthly_price                       3324 non-null object
# security_deposit                    5731 non-null object
# cleaning_fee                        7851 non-null object
# guests_included                     13335 non-null int64
# extra_people                        13335 non-null object
# minimum_nights                      13335 non-null int64
# maximum_nights                      13335 non-null int64
# calendar_updated                    13335 non-null object
# has_availability                    0 non-null float64
# availability_30                     13335 non-null int64
# availability_60                     13335 non-null int64
# availability_90                     13335 non-null int64
# availability_365                    13335 non-null int64
# calendar_last_scraped               13335 non-null object
# number_of_reviews                   13335 non-null int64
# first_review                        10542 non-null object
# last_review                         10541 non-null object
# review_scores_rating                10417 non-null float64
# review_scores_accuracy              10399 non-null float64
# review_scores_cleanliness           10405 non-null float64
# review_scores_checkin               10389 non-null float64
# review_scores_communication         10405 non-null float64
# review_scores_location              10387 non-null float64
# review_scores_value                 10387 non-null float64
# requires_license                    13335 non-null object
# license                             249 non-null object
# jurisdiction_names                  0 non-null float64
# instant_bookable                    13335 non-null object
# cancellation_policy                 13335 non-null object
# require_guest_profile_picture       13335 non-null object
# require_guest_phone_verification    13335 non-null object
# calculated_host_listings_count      13335 non-null int64
# reviews_per_month                   10542 non-null float64
# dtypes: float64(19), int64(13), object(63)
# memory usage: 9.7+ MB

# %%
#Existe alguna fila NULL?
print listing.isnull().any().any() 
print listing.shape
# Out:
# True
# (13335, 95)

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Vamos a tratar de encontrar cuántos valores nulos existen en cada columna!</span>
# </div>

# %%
listing.isnull().sum(axis=0)
# Out:
# id                                      0
# listing_url                             0
# scrape_id                               0
# last_scraped                            0
# name                                    0
# summary                               489
# space                                3635
# description                             6
# experiences_offered                     0
# neighborhood_overview                5027
# notes                                8298
# transit                              5071
# access                               5789
# interaction                          5812
# house_rules                          4669
# thumbnail_url                        2488
# medium_url                           2488
# picture_url                             0
# xl_picture_url                       2488
# host_id                                 0
# host_url                                0
# host_name                               3
# host_since                              3
# host_location                          42
# host_about                           5053
# host_response_time                   1713
# host_response_rate                   1713
# host_acceptance_rate                13335
# host_is_superhost                       3
# host_thumbnail_url                      3
# host_picture_url                        3
# host_neighbourhood                   3352
# host_listings_count                     3
# host_total_listings_count               3
# host_verifications                      0
# host_has_profile_pic                    3
# host_identity_verified                  3
# street                                  0
# neighbourhood                        4563
# neighbourhood_cleansed                  0
# neighbourhood_group_cleansed            0
# city                                    2
# state                                  43
# zipcode                               439
# market                                 50
# smart_location                          0
# country_code                            0
# country                                 1
# latitude                                0
# longitude                               0
# is_location_exact                       0
# property_type                           0
# room_type                               0
# accommodates                            0
# bathrooms                              50
# bedrooms                               23
# beds                                   49
# bed_type                                0
# amenities                               0
# square_feet                         12813
# price                                   0
# weekly_price                         9823
# monthly_price                       10011
# security_deposit                     7604
# cleaning_fee                         5484
# guests_included                         0
# extra_people                            0
# minimum_nights                          0
# maximum_nights                          0
# calendar_updated                        0
# has_availability                    13335
# availability_30                         0
# availability_60                         0
# availability_90                         0
# availability_365                        0
# calendar_last_scraped                   0
# number_of_reviews                       0
# first_review                         2793
# last_review                          2794
# review_scores_rating                 2918
# review_scores_accuracy               2936
# review_scores_cleanliness            2930
# review_scores_checkin                2946
# review_scores_communication          2930
# review_scores_location               2948
# review_scores_value                  2948
# requires_license                        0
# license                             13086
# jurisdiction_names                  13335
# instant_bookable                        0
# cancellation_policy                     0
# require_guest_profile_picture           0
# require_guest_phone_verification        0
# calculated_host_listings_count          0
# reviews_per_month                    2793
# dtype: int64

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">El paso anterior ya nos dió un indicio de que hay varias columnas con datos únicamente nulos.</span>
# </div>

# %% [markdown]
# <br><div style="text-align: left;">
#     <span style="font-weight: bold; color:#FF7674; font-family: 'Courier New'; font-size: 2em;">Arreglando los Missing Values</span>
# </div>
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Primero vamos a borrar las columnas cuyos valores sean todos Nulos, ya que no aportan nada. Una de las posibles causas puede haber sido una mala captura de datos.<br><br></span>
# </div>

# %%
listing.isnull().all()
# Out:
# id                                  False
# listing_url                         False
# scrape_id                           False
# last_scraped                        False
# name                                False
# summary                             False
# space                               False
# description                         False
# experiences_offered                 False
# neighborhood_overview               False
# notes                               False
# transit                             False
# access                              False
# interaction                         False
# house_rules                         False
# thumbnail_url                       False
# medium_url                          False
# picture_url                         False
# xl_picture_url                      False
# host_id                             False
# host_url                            False
# host_name                           False
# host_since                          False
# host_location                       False
# host_about                          False
# host_response_time                  False
# host_response_rate                  False
# host_acceptance_rate                 True
# host_is_superhost                   False
# host_thumbnail_url                  False
# host_picture_url                    False
# host_neighbourhood                  False
# host_listings_count                 False
# host_total_listings_count           False
# host_verifications                  False
# host_has_profile_pic                False
# host_identity_verified              False
# street                              False
# neighbourhood                       False
# neighbourhood_cleansed              False
# neighbourhood_group_cleansed        False
# city                                False
# state                               False
# zipcode                             False
# market                              False
# smart_location                      False
# country_code                        False
# country                             False
# latitude                            False
# longitude                           False
# is_location_exact                   False
# property_type                       False
# room_type                           False
# accommodates                        False
# bathrooms                           False
# bedrooms                            False
# beds                                False
# bed_type                            False
# amenities                           False
# square_feet                         False
# price                               False
# weekly_price                        False
# monthly_price                       False
# security_deposit                    False
# cleaning_fee                        False
# guests_included                     False
# extra_people                        False
# minimum_nights                      False
# maximum_nights                      False
# calendar_updated                    False
# has_availability                     True
# availability_30                     False
# availability_60                     False
# availability_90                     False
# availability_365                    False
# calendar_last_scraped               False
# number_of_reviews                   False
# first_review                        False
# last_review                         False
# review_scores_rating                False
# review_scores_accuracy              False
# review_scores_cleanliness           False
# review_scores_checkin               False
# review_scores_communication         False
# review_scores_location              False
# review_scores_value                 False
# requires_license                    False
# license                             False
# jurisdiction_names                   True
# instant_bookable                    False
# cancellation_policy                 False
# require_guest_profile_picture       False
# require_guest_phone_verification    False
# calculated_host_listings_count      False
# reviews_per_month                   False
# dtype: bool

# %%
print listing['jurisdiction_names'].unique()
print listing['has_availability'].unique()
print listing['host_acceptance_rate'].unique()
# Out:
# [ nan]
# [ nan]
# [ nan]

# %%
listing.drop('jurisdiction_names', axis=1, inplace=True)
listing.drop('has_availability', axis=1, inplace=True)
listing.drop('host_acceptance_rate', axis=1, inplace=True)

# %%
listing.shape
# Out:
# (13335, 92)

# %% [markdown]
# <br><div style="text-align: left;">
#     <span style="font-weight: bold; color:#FF7674; font-family: 'Courier New'; font-size: 2em;">Sampling</span>
# </div>
#
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Nuestra tabla de datos tiene muchas líneas o registros. Para no afectar el funcionamiento de nuestro ordenador, cuando queramos revisar los tipos de datos sólo miraremos pocas líneas a la vez. Ahora bien, en vez de mirar las mismas 2, 5 ó 10 líneas principales cada vez, aplicaremos lo siguiente con lo que conseguiremos ver una muestra aleatoria diferente en nuestro head(). De esta manera, nos aseguramos de que los datos no estén en ningún orden particular cuando probamos el muestreo (como tomar filas de arriba o de abajo) al mezclar aleatoriamente las filas.<br><br></span>
# </div>

# %%
#Shuffle de las filas de "listing" para que obtengamos una muestra distribuida cuando mostramos el head()

listing = listing.reindex(np.random.permutation(listing.index))
listing.head(3)
# Out:
#              id                            listing_url       scrape_id  \
# 8965   18095441  https://www.airbnb.com/rooms/18095441  20170407214119
# 5575    7745816   https://www.airbnb.com/rooms/7745816  20170407214119
# 11498   7469234   https://www.airbnb.com/rooms/7469234  20170407214119
#
#       last_scraped                                               name  \
# 8965    2017-04-08  Habitación con cama de matrimonio Barrio Salam...
# 5575    2017-04-08                 Precioso apto. al lado de Gran Vía
# 11498   2017-04-08           MADRID RIO room, luminous, metro station
#
#                                                  summary  \
# 8965   Habitación privada con cama de matrimonio. Der...
# 5575   Apartamento muy acogedor completamente reforma...
# 11498  MADRID RIO. Beautiful and bright room. 20 mete...
#
#                                                    space  \
# 8965                  La ubicación, limpieza y comodidad
# 5575   El apartamento consta de dos espacios, como se...
# 11498           Magnifient apartment, great common areas
#
#                                              description experiences_offered  \
# 8965   Habitación privada con cama de matrimonio. Der...                none
# 5575   Apartamento muy acogedor completamente reforma...                none
# 11498  MADRID RIO. Beautiful and bright room. 20 mete...                none
#
#                                    neighborhood_overview  \
# 8965                                               Bueno
# 5575   Localización inmejorable. El barrio es el míti...
# 11498  5 minutes walking from Madrid Rio y and Princi...
#
#                                                    notes  \
# 8965   Recomendado para viajes de negocios, placer ó ...
# 5575                                                 NaN
# 11498                                Car parking 12€/day
#
#                                                  transit  \
# 8965   Entrada del Metro de O'Donell, Goya y Manuel B...
# 5575   Hay varios metros al lado de casa: Noviciado, ...
# 11498  The closest metro station is less than 20 mete...
#
#                                                   access  \
# 8965   Cocina-comedor y baño a compartir con propietaria
# 5575   Al ser una vivienda de uso propio que se ofrec...
# 11498       Living room/dining room. Internet WiFi 20Mb.
#
#                                              interaction  \
# 8965   Sólo se coincidirá puntuslmente a lo largo del...
# 5575   Dispondréis de mi teléfono por si tuvierais cu...
# 11498  The keys are delivered in person. Facilities a...
#
#                                              house_rules  \
# 8965   Respetar las horas de silencio en la noche, y ...
# 5575   El apartamento se entrega limpio y en perfecto...
# 11498  Enjoy the apartment and respec it. Respect to ...
#
#                                            thumbnail_url  \
# 8965   https://a0.muscache.com/im/pictures/e848ba24-d...
# 5575                                                 NaN
# 11498                                                NaN
#
#                                               medium_url  \
# 8965   https://a0.muscache.com/im/pictures/e848ba24-d...
# 5575                                                 NaN
# 11498                                                NaN
#
#                                              picture_url  \
# 8965   https://a0.muscache.com/im/pictures/e848ba24-d...
# 5575   https://a0.muscache.com/im/pictures/98576927/7...
# 11498  https://a0.muscache.com/im/pictures/94700232/4...
#
#                                           xl_picture_url    host_id  \
# 8965   https://a0.muscache.com/im/pictures/e848ba24-d...  124597861
# 5575                                                 NaN   19227342
# 11498                                                NaN   24085430
#
#                                           host_url host_name  host_since  \
# 8965   https://www.airbnb.com/users/show/124597861    Esther  2017-04-06
# 5575    https://www.airbnb.com/users/show/19227342   Gabriel  2014-07-31
# 11498   https://www.airbnb.com/users/show/24085430   Lorenzo  2014-11-23
#
#                             host_location  \
# 8965   Madrid, Community of Madrid, Spain
# 5575   Madrid, Community of Madrid, Spain
# 11498  Madrid, Community of Madrid, Spain
#
#                                               host_about host_response_time  \
# 8965                                                 NaN                NaN
# 5575                                                 NaN       within a day
# 11498  Madrid, me gusta pasear, ir en bici, beber/com...       within a day
#
#       host_response_rate host_is_superhost  \
# 8965                 NaN                 f
# 5575                100%                 f
# 11498                86%                 f
#
#                                       host_thumbnail_url  \
# 8965   https://a0.muscache.com/im/pictures/7f61af8f-6...
# 5575   https://a0.muscache.com/im/users/19227342/prof...
# 11498  https://a0.muscache.com/im/users/24085430/prof...
#
#                                         host_picture_url host_neighbourhood  \
# 8965   https://a0.muscache.com/im/pictures/7f61af8f-6...                NaN
# 5575   https://a0.muscache.com/im/users/19227342/prof...           Malasaña
# 11498  https://a0.muscache.com/im/users/24085430/prof...          Argüelles
#
#        host_listings_count  host_total_listings_count  \
# 8965                   1.0                        1.0
# 5575                   1.0                        1.0
# 11498                 11.0                       11.0
#
#                                       host_verifications host_has_profile_pic  \
# 8965                      ['email', 'phone', 'facebook']                    t
# 5575                       ['email', 'phone', 'reviews']                    t
# 11498  ['email', 'phone', 'reviews', 'jumio', 'work_e...                    t
#
#       host_identity_verified  \
# 8965                       f
# 5575                       f
# 11498                      t
#
#                                                   street neighbourhood  \
# 8965                  Madrid, Comunidad de Madrid, Spain           NaN
# 5575   Malasaña, Madrid, Comunidad de Madrid 28004, S...      Malasaña
# 11498         Aluche, Madrid, Comunidad de Madrid, Spain        Aluche
#
#       neighbourhood_cleansed neighbourhood_group_cleansed    city  \
# 8965             Prosperidad                    Chamartín  Madrid
# 5575             Universidad                       Centro  Madrid
# 11498       Puerta del Angel                       Latina  Madrid
#
#                      state zipcode  market smart_location country_code  \
# 8965   Comunidad de Madrid     NaN  Madrid  Madrid, Spain           ES
# 5575   Comunidad de Madrid   28004  Madrid  Madrid, Spain           ES
# 11498  Comunidad de Madrid     NaN  Madrid  Madrid, Spain           ES
#
#       country   latitude  longitude is_location_exact property_type  \
# 8965    Spain  40.440998  -3.678284                 f         House
# 5575    Spain  40.425760  -3.707467                 t     Apartment
# 11498   Spain  40.414894  -3.724432                 f     Apartment
#
#              room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 8965      Private room             2        1.0       1.0   1.0  Real Bed
# 5575   Entire home/apt             2        1.0       1.0   1.0  Real Bed
# 11498     Private room             2        1.0       1.0   1.0  Real Bed
#
#                                                amenities  square_feet   price  \
# 8965   {"Cable TV","Wireless Internet",Kitchen,"Smoki...          NaN  $50.00
# 5575   {TV,Internet,"Wireless Internet","Air conditio...          NaN  $52.00
# 11498  {TV,Internet,"Wireless Internet","Air conditio...          NaN  $39.00
#
#       weekly_price monthly_price security_deposit cleaning_fee  \
# 8965           NaN           NaN              NaN          NaN
# 5575           NaN           NaN          $500.00          NaN
# 11498      $290.00       $802.00              NaN       $10.00
#
#        guests_included extra_people  minimum_nights  maximum_nights  \
# 8965                 1        $0.00               1               7
# 5575                 2       $25.00               2            1125
# 11498                1        $0.00              30             365
#
#       calendar_updated  availability_30  availability_60  availability_90  \
# 8965             today               22               52               82
# 5575      2 months ago                0                0                0
# 11498      7 weeks ago                0                1                7
#
#        availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 8965                357            2017-04-07                  0          NaN
# 5575                  0            2017-04-08                  5   2016-05-30
# 11498                97            2017-04-08                  2   2015-09-05
#
#       last_review  review_scores_rating  review_scores_accuracy  \
# 8965          NaN                   NaN                     NaN
# 5575   2016-11-13                  92.0                    10.0
# 11498  2016-11-08                  90.0                     9.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 8965                         NaN                    NaN
# 5575                        10.0                   10.0
# 11498                        8.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# 8965                           NaN                     NaN
# 5575                          10.0                     9.0
# 11498                          9.0                    10.0
#
#        review_scores_value requires_license license instant_bookable  \
# 8965                   NaN                t     NaN                f
# 5575                   9.0                t     NaN                f
# 11498                 10.0                t     NaN                f
#
#       cancellation_policy require_guest_profile_picture  \
# 8965             moderate                             f
# 5575               strict                             f
# 11498            flexible                             f
#
#       require_guest_phone_verification  calculated_host_listings_count  \
# 8965                                 f                               1
# 5575                                 f                               1
# 11498                                f                              10
#
#        reviews_per_month
# 8965                 NaN
# 5575                0.48
# 11498               0.10

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Existen otras columnas con datos que no nos interesan, por ellos procederemos a eliminarlas:
# <br></span>
# </div>

# %%
delete = ['listing_url', 'scrape_id', 'last_scraped', 'thumbnail_url', 'medium_url','country_code','calendar_last_scraped', 
          'is_location_exact', 'host_neighbourhood', 'picture_url', 'xl_picture_url', 'host_thumbnail_url', 'host_picture_url', 
          'summary', 'description','host_url', 'experiences_offered', 'space', 'neighborhood_overview', 'notes', 'transit', 
          'access', 'interaction', 'house_rules', 'host_about', 'host_response_time', 'host_response_rate', 'square_feet', 
          'license']   
len(delete)
# Out:
# 29

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">El dato de "square_feet" lo borramos porque contiene muchos datos nulos, aunque podría ser un dato interesante para -por ejemplo- determinar el precio de alquiler del piso; aunque en el caso de AirBnB (si vamos a la concepción inicial de la idea de la compañia: compartir sofá) también podría considerarse como un dato menor.
# <br></span>
# </div>

# %%
for i in range(0,len(delete)):
    listing.drop(delete[i], axis=1, inplace=True)

# %%
listing.shape
# Out:
# (13335, 63)

# %%
listing = listing.reindex(np.random.permutation(listing.index))
listing.head(3)
# Out:
#             id                                 name   host_id       host_name  \
# 9135   1690312  Apartamento 200m2 para 5/6 personas   8815003           Maite
# 441    4678105   Central sunny apartment with views  17705919  Barbara Y Javi
# 5021  13091807  long rental study old town madrid 2  21137168             Ale
#
#       host_since                       host_location host_is_superhost  \
# 9135  2013-09-13  Madrid, Community of Madrid, Spain                 f
# 441   2014-07-06  Madrid, Community of Madrid, Spain                 f
# 5021  2014-09-09                              Spain                  f
#
#       host_listings_count  host_total_listings_count  \
# 9135                  2.0                        2.0
# 441                   1.0                        1.0
# 5021                  4.0                        4.0
#
#                           host_verifications host_has_profile_pic  \
# 9135  ['email', 'phone', 'reviews', 'jumio']                    t
# 441   ['email', 'phone', 'reviews', 'jumio']                    t
# 5021           ['email', 'phone', 'reviews']                    t
#
#      host_identity_verified  \
# 9135                      t
# 441                       t
# 5021                      f
#
#                                                  street neighbourhood  \
# 9135           Madrid, Community of Madrid 28016, Spain           NaN
# 441            Madrid, Comunidad de Madrid 28005, Spain           NaN
# 5021  Malasaña, Madrid, Comunidad de Madrid 28004, S...      Malasaña
#
#      neighbourhood_cleansed neighbourhood_group_cleansed    city  \
# 9135         Hispanoamérica                    Chamartín  Madrid
# 441                 Palacio                       Centro  Madrid
# 5021            Universidad                       Centro  Madrid
#
#                     state zipcode  market smart_location country   latitude  \
# 9135  Community of Madrid   28016  Madrid  Madrid, Spain   Spain  40.456181
# 441   Comunidad de Madrid   28005  Madrid  Madrid, Spain   Spain  40.412441
# 5021  Comunidad de Madrid   28004  Madrid  Madrid, Spain   Spain  40.426694
#
#       longitude property_type        room_type  accommodates  bathrooms  \
# 9135  -3.676956     Apartment  Entire home/apt             6        2.0
# 441   -3.711110     Apartment  Entire home/apt             2        1.0
# 5021  -3.707727     Apartment     Private room             2        1.0
#
#       bedrooms  beds  bed_type  \
# 9135       3.0   3.0  Real Bed
# 441        2.0   2.0  Real Bed
# 5021       2.0   1.0  Real Bed
#
#                                               amenities    price weekly_price  \
# 9135  {TV,"Cable TV",Internet,"Wireless Internet",Ki...  $200.00          NaN
# 441   {TV,Internet,"Wireless Internet",Kitchen,"Elev...  $100.00          NaN
# 5021  {Internet,"Wireless Internet","Air conditionin...   $39.00          NaN
#
#      monthly_price security_deposit cleaning_fee  guests_included  \
# 9135           NaN          $500.00          NaN                1
# 441            NaN          $150.00       $10.00                1
# 5021           NaN              NaN          NaN                1
#
#      extra_people  minimum_nights  maximum_nights calendar_updated  \
# 9135       $50.00               2               7      2 weeks ago
# 441         $0.00               2            1125      2 weeks ago
# 5021        $0.00               7             365            today
#
#       availability_30  availability_60  availability_90  availability_365  \
# 9135               30               60               90               365
# 441                 0                6               36               311
# 5021                7                9               29               281
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 9135                  1   2015-05-24  2015-05-24                  80.0
# 441                  20   2015-02-01  2016-10-04                  94.0
# 5021                  2   2017-03-07  2017-03-20                  80.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 9135                     8.0                       10.0
# 441                      9.0                        9.0
# 5021                    10.0                        9.0
#
#       review_scores_checkin  review_scores_communication  \
# 9135                   10.0                          8.0
# 441                    10.0                         10.0
# 5021                   10.0                          9.0
#
#       review_scores_location  review_scores_value requires_license  \
# 9135                    10.0                  8.0                t
# 441                     10.0                  9.0                t
# 5021                    10.0                 10.0                t
#
#      instant_bookable cancellation_policy require_guest_profile_picture  \
# 9135                f            flexible                             f
# 441                 f            flexible                             f
# 5021                t              strict                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 9135                                f                               2
# 441                                 f                               1
# 5021                                f                               4
#
#       reviews_per_month
# 9135               0.04
# 441                0.75
# 5021               1.82

# %%
listing.price.head()
# Out:
# 9135     $200.00
# 441      $100.00
# 5021      $39.00
# 12574    $120.00
# 2928      $60.00
# Name: price, dtype: object

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Debo eliminar el simbolo de dolar en la columna de precio y convertirlo en un dato tipo float.<br></span>
# </div>

# %%
def transform_price(df, variables=None):
    df = df.copy()
    for variable in variables:
        df[variable] = df[variable].str.strip('$').str.replace(',', '') \
            # Remove dollar signs and thousands separators
        df[variable] = df[variable].astype(np.float64)
    return df


vars_price = ['cleaning_fee', 'price', 'extra_people', 'weekly_price', 'monthly_price' ]
listing = transform_price(listing, vars_price)

# %%
listing['price'].head(5)
# Out:
# 9135     200.0
# 441      100.0
# 5021      39.0
# 12574    120.0
# 2928      60.0
# Name: price, dtype: float64

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">También se podría hacer de la siguiente manera:<br><br></span></div>
#
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.2em;"> listing['price']=listing['price'].str.strip('$').str.replace(',', '') <br>
# listing['price'] = pd.to_numeric(listing.price)</span></div>

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">O tambien, quitamos el símbolo de $ y el separador de miles en los valores no nulos "NA":
# <br><br></span></div>
#
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.2em;">listing['price'] = listing.loc[listing.price.notnull()].price.apply(lambda x: re.sub('$', '', x))<br>
# listing['price'] = pd.to_numeric(listing.price)
# <br></span></div>

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Seguimos limpiando datos...<br></span>
# </div>

# %%
variables = ['state', 'city', 'market', 'smart_location', 'country', 'neighbourhood', 'neighbourhood_cleansed',
             'neighbourhood_group_cleansed', 'host_location', 'street']

for i in range(0,len(variables)-1):
    print variables[i]
    print listing[variables[i]].unique()
    print ''
# Out:
# state
# ['Community of Madrid' 'Comunidad de Madrid' nan 'Madrid'
#  '\xe9\xa6\xac\xe5\xbe\xb7\xe9\x87\x8c\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8d\x80'
#  'madrid'
#  '\xe9\xa9\xac\xe5\xbe\xb7\xe9\x87\x8c\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8c\xba'
#  'Communaut\xc3\xa9 de Madrid' 'Madrid \nMadrid' 'Salerno Fisciano' 'Spain'
#  'Madrid, Spain' 'Espa\xc3\xb1a' 'Autonome Gemeinschaft Madrid'
#  '\xe9\xa9\xac\xe5\xbe\xb7\xe9\x87\x8c' '28' 'Usera' 'Valencian Community'
#  'MADRID' 'Madrid Espa\xc3\xb1a' ' ' 'Alicante' '  ' 'Espa\xc5\x84a'
#  'Madrid capital' 'La Habana' 'Barcelona'
#  '\xe8\xa5\xbf\xe7\x8f\xad\xe7\x89\x99' 'Espa\xc3\xb1a,Madrid'
#  'Regi\xc3\xa3o Aut\xc3\xb4noma de Madrid']
#
# city
# ['Madrid' '\xe9\xa6\xac\xe5\xbe\xb7\xe9\x87\x8c'
#  'Madrid, Comunidad de Madrid, ES' '\xe9\xa9\xac\xe5\xbe\xb7\xe9\x87\x8c'
#  'Madrid ' 'Valderrodrigo' ' Madrid' 'Salerno' 'Pozuelo de Alarc\xc3\xb3n'
#  'San L\xc3\xa1zaro' 'M\xc3\xa1laga' 'Boadilla del Monte' 'Pozuelo'
#  'madrid' 'MADRID' 'MADRID ' 'Chueca, Madrid' nan 'villa verde bajo'
#  'Madrid, Comunidad de Madrid, ESPANA' 'San Fernando de Henares' 'Chiva'
#  'Centro, Madrid' 'Aravaca ' ' ' 'Onil' 'las matas  madrid' '  '
#  'Madrid, Vallecas (Fontarr\xc3\xb3n)' 'Centro' 'Madid' 'La Habana'
#  'Chueca' 'La Elipa' 'Aravaca (Madrid)' 'Motilla del Palancar' '\nDelicias'
#  'Delicias-Madrid' 'Barcelona ' 'Ventas' 'Malaga' 'Madri'
#  'Comunidad de Madrid']
#
# market
# ['Madrid' nan 'London' 'Deauville' 'Other (International)' 'Toledo']
#
# smart_location
# ['Madrid, Spain' '\xe9\xa6\xac\xe5\xbe\xb7\xe9\x87\x8c, Spain'
#  'Madrid, Comunidad de Madrid, ES, Spain'
#  '\xe9\xa9\xac\xe5\xbe\xb7\xe9\x87\x8c, Spain' 'Madrid , Spain'
#  'Valderrodrigo, Spain' ' Madrid, Spain' 'Salerno'
#  'Pozuelo de Alarc\xc3\xb3n, Spain' 'San L\xc3\xa1zaro, Spain'
#  'M\xc3\xa1laga, Spain' 'Boadilla del Monte, Spain' 'Pozuelo, Spain'
#  'madrid, Spain' 'MADRID, Spain' 'MADRID , Spain' 'Chueca, Madrid, Spain'
#  'villa verde bajo, Spain' 'Madrid, Comunidad de Madrid, ESPANA, Spain'
#  'San Fernando de Henares, Spain' 'Chiva, Spain' 'Centro, Madrid, Spain'
#  'Aravaca , Spain' 'ES, Spain' 'Onil, Spain' 'las matas  madrid, Spain'
#  'Madrid, Vallecas (Fontarr\xc3\xb3n), Spain' 'Centro, Spain'
#  'Madid, Spain' 'La Habana, Cuba' 'Chueca, Spain' 'La Elipa, Spain'
#  'Aravaca (Madrid), Spain' 'Motilla del Palancar, Spain'
#  '\nDelicias, Spain' 'Delicias-Madrid, Spain' 'Barcelona , Spain'
#  'Ventas, Spain' 'Malaga, Spain' 'Madri, Spain'
#  'Comunidad de Madrid, Spain']
#
# country
# ['Spain' nan 'Cuba']
#
# neighbourhood
# [nan 'Malasa\xc3\xb1a' 'Embajadores' 'Aluche' 'Delicias' 'Justicia'
#  'Ciudad Jardin' 'Cortes' 'Arg\xc3\xbcelles' 'Guindalera' 'Ciudad Lineal'
#  'Palos do Moguer' 'Cuatro Caminos' 'Arapiles' 'Carabanchel' 'Gaztambide'
#  'Sol' 'Hortaleza' 'Castilla' 'Adelfas' 'Pacifico' 'La Latina'
#  'Bellas Vistas' 'San Blas' 'Recoletos' 'Almagro' 'Acacias' 'Valdeacederas'
#  'Ibiza' 'Trafalgar' 'Fuente del Berro' 'Goya' 'El Tr\xc3\xa9ntaiseis'
#  'Prosperidad' 'Almenara' 'Hispanoam\xc3\xa9rica' 'Castillejos' 'Palacio'
#  'La Chopera' 'Legazpi' 'Moncloa' 'Castellana' 'Centro'
#  'Puente de Vallecas' 'Usera' 'Nueva Espa\xc3\xb1a' 'Imperial' 'Barajas'
#  'Lista' 'Moratalaz' 'Villaverde' 'Rios Rosas' 'Fuencarral-el Pardo'
#  'Berruguete' 'Jer\xc3\xb3nimos' 'El Viso' 'Chamber\xc3\xad' 'Retiro'
#  'Vallehermosa' 'Estrella' 'Vic\xc3\xa1lvaro' 'Tetu\xc3\xa1n'
#  'Villa de Vallecas' 'Fuencarral-El Pardo' 'Arganzuela' 'Atocha']
#
# neighbourhood_cleansed
# ['Hispanoam\xc3\xa9rica' 'Palacio' 'Universidad' 'Pueblo Nuevo'
#  'Embajadores' 'Puerta del Angel' 'Delicias' 'Arapiles' 'Justicia'
#  'Ciudad Jard\xc3\xadn' 'Fuente del Berro' 'Cortes' 'Arg\xc3\xbcelles'
#  'Guindalera' 'Costillares' 'Comillas' 'Palos de Moguer' 'Cuatro Caminos'
#  'Buenavista' 'Gaztambide' 'Sol' 'Acacias' 'Palomas' 'Lista' 'Castilla'
#  'Puerta Bonita' 'Vallehermoso' 'Adelfas' 'La Paz' 'Trafalgar'
#  'Vista Alegre' 'Pac\xc3\xadfico' 'Numancia' 'Bellas Vistas' 'Salvador'
#  'Recoletos' 'Almagro' 'Pradolongo' 'Ibiza' 'Imperial' 'Valdeacederas'
#  'Amposta' 'San Pascual' 'Castellana' 'Goya' 'Ni\xc3\xb1o Jes\xc3\xbas'
#  'Prosperidad' 'Almenara' 'Berruguete' 'Valdefuentes' 'Jer\xc3\xb3nimos'
#  'Castillejos' 'Colina' 'Los Rosales' 'Chopera' 'El Viso' 'Legazpi'
#  'Quintana' 'Casco Hist\xc3\xb3rico de Vic\xc3\xa1lvaro'
#  'Ciudad Universitaria' 'Simancas' 'San Isidro' 'Pinar del Rey' 'Canillas'
#  'Opa\xc3\xb1el' 'Los Angeles' 'Ventas' 'Palomeras Bajas' 'Zof\xc3\xado'
#  'Canillejas' 'Aluche' 'Nueva Espa\xc3\xb1a' 'Pilar' 'San Diego'
#  'San Ferm\xc3\xadn' 'Rios Rosas' 'Alameda de Osuna' 'Vinateros'
#  'San Juan Bautista' 'Valverde' 'Rosas' 'San Andr\xc3\xa9s' 'Casa de Campo'
#  'Pe\xc3\xb1agrande' 'Concepci\xc3\xb3n' 'Aravaca' 'Hell\xc3\xadn'
#  'Abrantes' 'Casco Hist\xc3\xb3rico de Vallecas' 'Atocha' 'Almendrales'
#  'Lucero' 'Piovera' 'Valdezarza' 'Entrev\xc3\xadas' 'Fontarr\xc3\xb3n'
#  'Casco Hist\xc3\xb3rico de Barajas' 'Moscard\xc3\xb3' 'Arcos' 'Portazgo'
#  'C\xc3\xa1rmenes' 'Apostol Santiago' 'Media Legua' 'San Cristobal'
#  'Valdemar\xc3\xadn' 'Aeropuerto' 'Marroquina' 'Mirasierra'
#  'Palomeras Sureste' 'Rejas' 'Pavones' 'Aguilas' 'Estrella' 'Ambroz'
#  'Corralejos' 'Tim\xc3\xb3n' 'Campamento' 'Orcasur' 'Butarque' 'El Goloso'
#  'Fuentelareina' 'Santa Eugenia' 'Cuatro Vientos' 'Orcasitas'
#  'El Plant\xc3\xado' 'El Pardo']
#
# neighbourhood_group_cleansed
# ['Chamart\xc3\xadn' 'Centro' 'Ciudad Lineal' 'Latina' 'Arganzuela'
#  'Chamber\xc3\xad' 'Salamanca' 'Moncloa - Aravaca' 'Carabanchel'
#  'Tetu\xc3\xa1n' 'Hortaleza' 'Retiro' 'Fuencarral - El Pardo'
#  'Puente de Vallecas' 'San Blas - Canillejas' 'Usera' 'Villaverde'
#  'Vic\xc3\xa1lvaro' 'Barajas' 'Moratalaz' 'Villa de Vallecas']
#
# host_location
# ['Madrid, Community of Madrid, Spain' 'Spain ' 'ES' 'Madrid, Madrid, Spain'
#  'US' 'Torremolinos, Andaluc\xc3\xada, Spain'
#  'Alexandria, Virginia, United States' 'Marbella, Andaluc\xc3\xada, Spain'
#  'Taipei City, Taiwan' 'Spain' 'Majadahonda, Madrid, Spain'
#  'Pozuelo de Alarc\xc3\xb3n, Comunidad de Madrid, Spain' 'Espa\xc3\xb1a'
#  'Bogajo, Castilla y Le\xc3\xb3n, Spain'
#  'Villanueva del Pardillo, Comunidad de Madrid, Spain'
#  'Eureka, California, United States'
#  'Vitoria-Gasteiz, Basque Country, Spain'
#  'Majadahonda, Comunidad de Madrid, Spain'
#  'Sevilla, Andaluc\xc3\xada, Spain'
#  'Alcala de Henares, Community of Madrid, Spain' 'London'
#  'Aranjuez, Community of Madrid, Spain' 'Capital District, Venezuela'
#  'Beirut, Beirut, Lebanon' 'CA' 'Torrelodones, Comunidad de Madrid, Spain'
#  'Toulouse, Midi-Pyr\xc3\xa9n\xc3\xa9es, France'
#  'Paris, \xc3\x8ele-de-France, France' 'Barcelona, Catalu\xc3\xb1a, Spain'
#  'Bethesda, Maryland, United States'
#  'Viso del Marqu\xc3\xa9s, Castilla-La Mancha, Spain'
#  'Salerno, Campania, Italy' 'Colombia/ Espa\xc3\xb1a/ Italia'
#  'Parla, Community of Madrid, Spain' 'New York, New York, United States'
#  'London, England, United Kingdom' 'Burgos, Castilla y Le\xc3\xb3n, Spain'
#  'Luxembourg' 'Barcelona, Catalonia, Spain' 'France'
#  'Dubai, Dubai, United Arab Emirates' 'Community of Madrid, Spain'
#  'Valencia, Valencian Community, Spain'
#  'Legan\xc3\xa9s, Community of Madrid, Spain' 'CN'
#  'Seville, Andalusia, Spain'
#  'Paracuellos de Jarama, Comunidad de Madrid, Spain'
#  'Las Palmas de Gran Canaria, Canary Islands, Spain' 'Andalusia, Spain'
#  'Segovia, Castile and Le\xc3\xb3n, Spain'
#  'Casco Hist\xc3\xb3rico De Calarc\xc3\xa1, Quindio, Colombia'
#  'Irun, Basque Country, Spain' 'A Coru\xc3\xb1a, Galicia, Spain'
#  'Le Mesnil-Esnard, Normandy, France'
#  'San Sebasti\xc3\xa1n, Basque Country, Spain'
#  'Getafe, Comunidad de Madrid, Spain' 'Cabra, Andalusia, Spain'
#  'La Mesa, California, United States'
#  'Le Chesnay, \xc3\x8ele-de-France, France'
#  'Logro\xc3\xb1o, La Rioja, Spain' 'Fuengirola, Andaluc\xc3\xada, Spain'
#  'Navalcarnero, Community of Madrid, Spain' 'Fitzroy, Victoria, Australia'
#  'Bogota, Bogota, Colombia' 'Perugia, Umbria, Italy'
#  'Ajaccio, Corsica, France' 'Brussels, Brussels, Belgium'
#  'Albox, Andaluc\xc3\xada, Spain' 'Las Rozas, Community of Madrid, Spain'
#  'Edinburgh, Scotland, United Kingdom' nan 'Lima, Lima, Peru'
#  'Basel, Basel-Stadt, Switzerland' 'Mallorca, Spain' 'PA'
#  'Alpedrete, Madrid, Spain' 'Warsaw, Masovian Voivodeship, Poland'
#  'Santa Cruz de la Palma, Canary Islands, Spain' 'Espana' 'Buenos Aires'
#  'FR' 'Salamanca, Castilla y Le\xc3\xb3n, Spain'
#  'Palma, Balearic Islands, Spain'
#  'Argentina, Castilla y Le\xc3\xb3n, Spain' 'Naples, Campania, Italy'
#  'Galapagar, Comunidad de Madrid, Spain' 'Corella, Navarre, Spain'
#  'Ciempozuelos, Comunidad de Madrid, Spain'
#  'Arroyomolinos, Community of Madrid, Spain'
#  'Velilla de San Antonio, Community of Madrid, Spain' 'IT'
#  'Granada, Andalusia, Spain' 'C\xc3\xb3rdoba, Andalusia, Spain'
#  'Arrecife, Canary Islands, Spain'
#  'Santa Cruz de Tenerife, Canary Islands, Spain'
#  'Rez\xc3\xa9, Pays de la Loire, France'
#  'Benalm\xc3\xa1dena, Andaluc\xc3\xada, Spain' 'Berlin, Berlin, Germany'
#  'Salamanca, Castile and Le\xc3\xb3n, Spain' 'Chueca,Madrid'
#  'Fort Pierce, Florida, United States'
#  'Amsterdam, North Holland, Netherlands' 'Ibiza, Balearic Islands, Spain'
#  'El Escorial, Community of Madrid, Spain'
#  'El Escorial, Comunidad de Madrid, Spain'
#  'Alcobendas, Comunidad de Madrid, Spain' 'Canicatt\xc3\xac, Sicily, Italy'
#  'Deutschland' 'Seattle, Washington, United States'
#  'Alcobendas, Community of Madrid, Spain'
#  'en Madrid cerca de El Escorial, localidad hist\xc3\xb3rica'
#  'Pozuelo de Alarc\xc3\xb3n, Community of Madrid, Spain'
#  'Seoul, South Korea' 'Bail\xc3\xa9n, Andalusia, Spain'
#  'Bilbao, Basque Country, Spain' 'Zaragoza, Aragon, Spain'
#  'Guadalajara, Castilla-La Mancha, Spain'
#  'Guadalajara, Castile-La Mancha, Spain' 'Mechelen, Flanders, Belgium'
#  'Santa Cruz de la Zarza, Castilla-La Mancha, Spain' 'NL'
#  'Lleida, Catalonia, Spain' 'Tres Cantos, Community of Madrid, Spain'
#  'San Antonio, Valparaiso, Chile' 'Madrid, New York, United States'
#  'Region of Murcia, Spain' 'City of Brussels, Brussels, Belgium'
#  'Espa\xc3\xb1a ' 'Calamonte, Extremadura, Spain'
#  'Toronto, Ontario, Canada' 'Calle Mirasierra 16 bajo izquierda'
#  'Caracas, Capital District, Venezuela'
#  'Moraira, Comunidad Valenciana, Spain' 'United States'
#  'Vivo en Madrid, en el mismo piso que ofrezco, pero es muy grande, quiz\xc3\xa1 nos divisemos en el sal\xc3\xb3n.'
#  'Hong Kong' 'San Mart\xc3\xadn de la Vega, Comunidad de Madrid, Spain'
#  'Azuqueca de Henares, Castile-La Mancha, Spain'
#  'Doctor Tolosa Latour 19 escalera 2   1-A' 'Hilo, Hawaii, United States'
#  'Daganzo de Arriba, Comunidad de Madrid, Spain'
#  'Santiago de Compostela, Galicia, Spain' 'Geneva, Geneva, Switzerland'
#  'Tomelloso, Castilla-La Mancha, Spain' 'Pinto, Community of Madrid, Spain'
#  'Altea, Valencian Community, Spain' 'Madrid, Caraga, Philippines'
#  'En el mismo  piso' 'Munich, Bavaria, Germany'
#  'Berkeley, California, United States'
#  'Alicante, Valencian Community, Spain'
#  'Quintanar de la Orden, Castile-La Mancha, Spain'
#  'M\xc3\xa1laga, Andalusia, Spain' 'Albacete, Castile-La Mancha, Spain'
#  'Palma de Mallorca, Balearic Islands, Spain'
#  'Montreal, Qu\xc3\xa9bec, Canada' 'Bordeaux, Aquitaine, France'
#  'Mahon, Balearic Islands, Spain'
#  'Las Pedro\xc3\xb1eras, Castilla-La Mancha, Spain' 'Rome, Lazio, Italy'
#  'Venice, Veneto, Italy' 'Sydney, New South Wales, Australia'
#  'Lake Forest, California, United States' 'X\xc3\xa0tiva, Valencia, Spain'
#  'Grenoble, Auvergne-Rh\xc3\xb4ne-Alpes, France'
#  'Fuentes, Castilla-La Mancha, Spain'
#  'Amsterdam, Noord-Holland, The Netherlands'
#  'Alcorc\xc3\xb3n, Comunidad de Madrid, Spain'
#  'Ramos Mej\xc3\xada, Buenos Aires Province, Argentina'
#  'Ontinyent, Valencian Community, Spain'
#  'Albacete, Castilla-La Mancha, Spain' 'United Kingdom' 'AU'
#  'Majadahonda, Community of Madrid, Spain' 'Spain\n' 'Kfar Saba, Israel'
#  'Villanueva de San Mancio, Castilla y Le\xc3\xb3n, Spain'
#  'eloy gonzalo 19, 2\xc2\xbab' 'Chicago, Illinois, United States'
#  'D\xc3\xbcsseldorf, North Rhine-Westphalia, Germany'
#  'Almer\xc3\xada, Andalusia, Spain' 'London, UK'
#  'M\xc3\xb3stoles, Community of Madrid, Spain' ' Spain'
#  'Montevideo, Montevideo Department, Uruguay'
#  '\xc3\x81vila\xe2\x80\x8e, Castile and Le\xc3\xb3n, Spain'
#  'Vivo entre Madrid y Mallorca.' 'Nuremberg, Bavaria, Germany'
#  'Lausanne, Vaud, Switzerland' 'Reykjav\xc3\xadk, Capital Region, Iceland'
#  'El Masnou, Catalonia, Spain' 'Barranquilla, Atlantico, Colombia' 'DK'
#  'C\xc3\xa1diz, Andalusia, Spain' 'London, United Kingdom'
#  'Pozuelo de Alarc\xc3\xb3n, Madrid, Spain' 'Galicia, Spain'
#  'Alpedrete, Comunidad de Madrid, Spain'
#  'Santiago, Santiago Metropolitan Region, Chile'
#  'Newark, New Jersey, United States'
#  'Alhaur\xc3\xadn de la Torre, Andalusia, Spain'
#  'En Madrid, en el coraz\xc3\xb3n del barrio de Malasa\xc3\xb1a'
#  'Burjassot, Valencian Community, Spain' 'Lisbon, Lisbon, Portugal'
#  'George Town, George Town, Cayman Islands' 'Colombia'
#  'Miles City, Montana, United States'
#  'Zurich, Canton of Zurich, Switzerland' 'Florence, Tuscany, Italy'
#  'Cambridge, England, United Kingdom' 'Norwalk, Connecticut, United States'
#  'Hontanares de Eresma, Castilla y Le\xc3\xb3n, Spain' 'spain'
#  'Boadilla del Monte, Comunidad de Madrid, Spain' 'SI'
#  'Antwerp, Flanders, Belgium'
#  'San Sebasti\xc3\xa1n de los Reyes, Community of Madrid, Spain'
#  'Oviedo, Asturias, Spain' 'Dublin, Dublin, Ireland' 'Between Spain & USA'
#  'ESPA\xc3\x91A'
#  'Plaza de Espa\xc3\xb1a number 7. 9th floor, door J - 35007 - Las Palmas de Gran Canaria - Canary Islands'
#  'El Berrueco, Comunidad de Madrid, Spain'
#  'Chapiner\xc3\xada, Comunidad de Madrid, Spain'
#  'Mexico City, Mexico City, Mexico'
#  'Rio de Janeiro, State of Rio de Janeiro, Brazil'
#  'Sant Josep de sa Talaia, Balearic Islands, Spain'
#  'Puntagorda, Canarias, Spain' 'London, Reino Unido'
#  'El Molar, Comunidad de Madrid, Spain'
#  'Parque Coimbra, Comunidad de Madrid, Spain'
#  'Magdalena Del Mar, Lima, Peru' 'Colombia, Huila, Colombia'
#  'Los Angeles, California, United States' 'Marbella, Andalusia, Spain'
#  'St. Joseph, Minnesota, United States' 'Madrid'
#  'Miami, Florida, United States'
#  'Cardenal Mendoza 28, 3A, Madrid. cp. 28011' 'Calafell, Catalonia, Spain'
#  'Venezuela' 'Huy, Walloon Region, Belgium'
#  'Villaviciosa de Od\xc3\xb3n, Community of Madrid, Spain'
#  'Sanya, Hainan, China' 'Stavanger, Norway' 'VE'
#  'Aunay-sous-Auneau, Centre-Val de Loire, France'
#  'Guillermo Rolland, 5-4\xc2\xba Ext.Iz.' 'Rouen, Upper Normandy, France'
#  'Santander, Cantabria, Spain' 'ES '
#  'San Sebasti\xc3\xa1n de los Reyes, Comunidad de Madrid, Spain'
#  'Las Palmas de Gran Canaria, Canarias, Spain'
#  'Nairobi, Nairobi County, Kenya' 'london ' 'Utrecht, Utrecht, Netherlands'
#  'Fuenlabrada, Comunidad de Madrid, Spain'
#  'La Tablada, Buenos Aires Province, Argentina'
#  'Valladolid, Castilla y Le\xc3\xb3n, Spain' 'Mexico'
#  'Houston, Texas, United States'
#  'Villaviciosa de Od\xc3\xb3n, Comunidad de Madrid, Spain'
#  'Prague, Prague, Czech Republic'
#  'Molina de Segura, Regi\xc3\xb3n de Murcia, Spain' 'Irlanda'
#  'Jerez, Andalusia, Spain' 'Pattaya, Chon Buri, Thailand'
#  'Evora, \xc3\x89vora District, Portugal' 'Cagliari, Sardegna, Italy'
#  'Panama, Panama, Panama' 'Vilamarxant, Valencian Community, Spain'
#  'Switzerland' 'espa\xc3\xb1a' 'Avenida Ciudad de Barcelona, 19, 6to Izq'
#  'Torino, Piedmont, Italy' 'Sliema, Malta'
#  'Geneva, Canton of Geneva, Switzerland' 'UK' 'M\xc3\xa9xico, DF'
#  'Quito, Pichincha, Ecuador'
#  'I was born and have always lived in this wonderful city'
#  'El Prat de Llobregat, Catalonia, Spain' '-'
#  'S\xc3\xa3o Paulo, S\xc3\xa3o Paulo, Brazil' 'Victoria, Australia'
#  'Cordova, Andaluc\xc3\xada, Spain' 'Varese, Lombardia, Italy'
#  'Rivas-Vaciamadrid, Comunidad de Madrid, Spain'
#  'Boadilla del Monte, Community of Madrid, Spain' 'C/ Magdalena 11, 3 iz'
#  'Auderghem, Brussels, Belgium' 'Algete, Community of Madrid, Spain'
#  'Lyon, Rhone-Alpes, France' 'Pozuelo, Comunidad de Madrid, Spain'
#  'Amsterdam, North Holland, The Netherlands'
#  'Cluj-Napoca, Cluj County, Romania' 'Vigo, Galicia, Spain'
#  'Florida, United States' 'Singapore' 'Madrid, SP, Spain'
#  'Riga, Riga, Latvia' 'Pinto, Comunidad de Madrid, Spain'
#  'Miami Beach, Florida, United States' 'Pamplona, Navarre, Spain'
#  'Santa Eul\xc3\xa0ria des Riu, Balearic Islands, Spain'
#  'Fuerteventura, Canarias, Spain' 'Santa Monica, California, United States'
#  'Villanueva de Perales, Community of Madrid, Spain'
#  'Santa Cruz de la Sierra, Santa Cruz Department, Bolivia'
#  'Santa Cruz de Tenerife, Canarias, Spain'
#  'Tracy, California, United States' 'Alfaro, La Rioja, Spain'
#  'Cartagena, Region of Murcia, Spain'
#  'Sucy-en-Brie, \xc3\x8ele-de-France, France'
#  'Mexico City, Federal District, Mexico' 'GB'
#  'San Sebastian, Basque Country, Spain' ' Spain,  Espa\xc3\xb1a,'
#  'Lugo, Galicia, Spain' 'Toledo, Castile-La Mancha, Spain'
#  'Cotia, S\xc3\xa3o Paulo, Brazil' 'Stockholm, Stockholm County, Sweden'
#  'Newport News, Virginia, United States' 'Saumur, Pays de la Loire, France'
#  'Torrelodones, Community of Madrid, Spain'
#  'Santa Coloma de Gramenet, Catalunya, Spain'
#  'Rosh Ha`Ayin, Hamerkaz, Israel' 'Nairobi, Nairobi, Kenya'
#  'Valdemorillo, Comunidad de Madrid, Spain' 'Cuba' 'MX'
#  'Sandbach, England, United Kingdom' 'Chiva, Valencian Community, Spain'
#  'Joaqu\xc3\xadn Mar\xc3\xada L\xc3\xb3pez 11 S\xc3\xb3tano B'
#  'Haro, La Rioja, Spain'
#  'Caluire-et-Cuire, Auvergne-Rh\xc3\xb4ne-Alpes, France'
#  'Aranjuez, Comunidad de Madrid, Spain' 'Barquisimeto, Lara, Venezuela'
#  'Bremen, Bremen, Germany' 'C/Monederos 5 BajoB'
#  'Villanueva de la Ca\xc3\xb1ada, Community of Madrid, Spain'
#  'Key Biscayne, Florida, United States' 'Hamburg, Hamburg, Germany'
#  'Kitzbuhel, Tyrol, Austria' 'Oleiros, Galicia, Spain'
#  'Mambajao, Northern Mindanao, Philippines' 'Istanbul, TR'
#  'El Puerto de Santa Mar\xc3\xada, Andalusia, Spain' 'Mallorca'
#  'Sutton Coldfield, England, United Kingdom'
#  'Naples, Florida, United States' 'Zurich, Zurich, Switzerland'
#  'Cartagena, Regi\xc3\xb3n de Murcia, Spain' 'Germany'
#  'San Diego, California, United States' 'Rafael Boti, 8 2\xc2\xbaA'
#  'Aloc\xc3\xa9n, Castilla-La Mancha, Spain' 'DE'
#  'Orlando, Florida, United States' 'La Orotava, Canarias, Spain' 'BE'
#  'Netherlands' 'calle nanclares de oca, 1 Portal d bajo d cp 28022'
#  'Curitiba, State of Paran\xc3\xa1, Brazil'
#  'Saillagouse, Languedoc-Roussillon-Midi-Pyr\xc3\xa9n\xc3\xa9es, France'
#  'Calle Gomes de Mora n6 4planta derecha.' 'Milan, Lombardy, Italy'
#  'Boadilla del Monte' 'Puerto La Cruz, Anzoategui, Venezuela' 'TW'
#  'Onil, Comunidad Valenciana, Spain' 'AS'
#  'Fuenlabrada, Community of Madrid, Spain'
#  'Lima District, Lima Region, Peru' 'Croydon, London'
#  'Cabanillas del Campo, Castilla-La Mancha, Spain'
#  'Nancy, Lorraine, France' 'Buenos Aires, Capital Federal, Argentina'
#  'Las Rozas, Madrid, Spain' 'Moscow, Moscow, Russia'
#  'Vilarmaior, Galicia, Spain' 'Milan, Lombardia, Italy'
#  'Schaerbeek, Brussels, Belgium' 'Monterfil, Brittany, France' 'France '
#  'Alcoi, Valencian Community, Spain' 'Boston, Massachusetts, United States'
#  'Santiago Metropolitan Region, Chile' 'Galdakao, Euskadi, Spain' 'RU'
#  'Washington, District of Columbia, United States' 'Catania, Sicily, Italy'
#  'Dakar, Dakar, Senegal' 'Ostiz, Navarra, Spain'
#  'La Albuera, Extremadura, Spain' 'Huesca, Aragon, Spain'
#  'Badajoz, Extremadura, Spain' 'calle quintana n2 10pta6'
#  'Oslo, Oslo, Kingdom of Norway'
#  'Fuencarral-El Pardo 10 minutes away from las Cuatro Torres'
#  'Prague, Hlavn\xc3\xad m\xc4\x9bsto Praha, Czech Republic'
#  'Dallas, North Carolina, United States'
#  'Fuencarral-El Pardo, Community of Madrid, Spain'
#  'Vancouver, British Columbia, Canada'
#  'C\xc3\xa1ceres\xe2\x80\x8e, Extremadura, Spain'
#  'Murcia, Regi\xc3\xb3n de Murcia, Spain' 'Buenos Aires, Argentina'
#  'Miami Shores, Florida, United States' 'Oslo, Oslo, Norway'
#  'Miraflores de la Sierra, Community of Madrid, Spain'
#  'Le\xc3\xb3n, Castile and Le\xc3\xb3n, Spain'
#  'Philadelphia, Pennsylvania, United States'
#  'San Nicandro Garganico, Puglia, Italy'
#  'Metz, Alsace-Champagne-Ardenne-Lorraine, France' 'Costa Rica'
#  'Vorarlberg, Austria' 'Madrid & Lake Tahoe'
#  'Gainesville, Florida, United States' 'Ireland' 'Montreal, Quebec, Canada'
#  'Mart\xc3\xadnez, Buenos Aires Province, Argentina'
#  'Etterbeek, Brussels, Belgium' 'D\xc3\xa9nia, Valencian Community, Spain'
#  'Arroyomolinos, Comunidad de Madrid, Spain'
#  'Calle Vicente Camar\xc3\xb3n 21, 2do derecha'
#  'Corrientes, Corrientes Province, Argentina' 'EC'
#  'Badalona, Catalonia, Spain' 'Alcorc\xc3\xb3n, Community of Madrid, Spain'
#  'Hallandale Beach, Florida, United States'
#  'Donostia-San Sebasti\xc3\xa1n, Basque Country, Spain' 'Latvia'
#  'glorieta de quevedo 4 3 izq' 'Zamora, Castile and Le\xc3\xb3n, Spain'
#  'Playa Honda, Regi\xc3\xb3n de Murcia, Spain' 'PH' 'California, USA'
#  'Buenos Aires, Autonomous City of Buenos Aires, Argentina'
#  'T\xc3\xb6nisvorst, North Rhine-Westphalia, Germany'
#  'Calle Carlos de Arniches 2 Int Izq' 'PT' 'Tarifa, Spain'
#  'Krak\xc3\xb3w, Lesser Poland Voivodeship, Poland'
#  'Alonso Cano 15 3\xc2\xbaB' 'Freiburg, Baden-Wurttemberg, Germany'
#  'Managua, Managua, Nicaragua' 'Gold Coast, Queensland'
#  'Cairo, Cairo Governorate, Egypt' 'Pompano Beach, Florida, United States'
#  'Brighton, England, United Kingdom' 'Piedmont, Italy'
#  'Colmenarejo, Comunidad de Madrid, Spain' 'En Mallorca'
#  'Calle Toledo, n\xc2\xba6 \xc3\x81tico 6'
#  'Porto Alegre, Rio Grande do Sul, Brazil' 'Xinzo de Limia, Galicia, Spain'
#  'La Plata, Buenos Aires Province, Argentina' 'Tampico, Tamaulipas, Mexico'
#  'California, United States' 'P\xc3\xa4wesin, Brandenburg, Germany'
#  'Santo Domingo, Distrito Nacional, Dominican Republic'
#  'Tallinn, Harju County, Estonia'
#  'San Mart\xc3\xadn de Porres, Lima Region, Peru'
#  'Hoyo de Manzanares, Community of Madrid, Spain'
#  'Leon, Guanajuato, Mexico'
#  'Jouy-le-Ch\xc3\xa2tel, \xc3\x8ele-de-France, France'
#  'Valencia, Valencia, Spain' 'Frankfurt, Hesse, Germany' 'Asturias'
#  'S\xc3\xa3o Paulo, State of S\xc3\xa3o Paulo, Brazil'
#  'Pozuelo, Community of Madrid, Spain' 'Cerca, en el Planeta'
#  'France and temporarily in Qatar' 'Vivimos en Aranjuez '
#  'Aldeanueva de Ebro, La Rioja, Spain' 'Dublin, County Dublin, Ireland'
#  'Valencia, Carabobo, Venezuela'
#  'Saint-F\xc3\xa9lix-de-Valois, Qu\xc3\xa9bec, Canada'
#  'Adelaide, South Australia, Australia'
#  'Paseo Castellana 243, 3\xc2\xba dcha; 28046 Madridf'
#  'San Juan, San Juan, Puerto Rico' 'BR'
#  'Cotos de Monterrey, Comunidad de Madrid, Spain'
#  'Valladolid, Castile and Le\xc3\xb3n, Spain'
#  'Calle Odonnell, 38, 7\xc2\xbaD' ' Comunidad de Madrid, Spain'
#  'Palencia, Castilla y Le\xc3\xb3n, Spain'
#  'L\xc3\xa9guevin, Occitanie, France'
#  'Topsfield, Massachusetts, United States'
#  'Villanueva del Pardillo, Community of Madrid, Spain'
#  'Las Palmas, Canary Islands, Spain' 'Arona, Canary Islands, Spain'
#  'Tarifa, Andalusia, Spain' 'Athens, Attica, Greece'
#  'Copenhagen, Capital Region of Denmark, Denmark'
#  'Torrej\xc3\xb3n de Ardoz, Comunidad de Madrid, Spain'
#  '\xc3\x85kersberga, Stockholm County, Sweden'
#  'Torrent, Valencian Community, Spain'
#  'Coslada, Comunidad de Madrid, Spain'
#  'Cuenca Alta del Manzanares, Comunidad de Madrid, Spain'
#  'Hanover, Lower Saxony, Germany' 'Tomares, Andalusia, Spain'
#  "Val-d'Is\xc3\xa8re, Rhone-Alpes, France" 'calle de la ruda 3 numero 3-3'
#  'Hawaiian Gardens, California, United States'
#  'Paris, Ile-de-France, France' 'london' 'Cadiz, Andaluc\xc3\xada, Spain'
#  'Caceres, Extremadura, Spain' 'Calasparra, Regi\xc3\xb3n de Murcia, Spain'
#  'Tres Cantos, Comunidad de Madrid, Spain' 'Mexico ' 'espana'
#  'Florian\xc3\xb3polis, State of Santa Catarina, Brazil' 'Israel'
#  'Munich, Bayern, Germany' 'Vi\xc3\xb1a del Mar, Valparaiso, Chile'
#  'Saverne, Alsace, France' 'Albox, Andalusia, Spain'
#  'Coslada, Community of Madrid, Spain'
#  'Saint Petersburg, Saint Petersburg, Russia']

# %%
state = ['Community of Madrid', '\xe9\xa9\xac\xe5\xbe\xb7\xe9\x87\x8c\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8c\xba',
         'Regi\xc3\xa3o Aut\xc3\xb4noma de Madrid', 'madrid', '\xe9\xa9\xac\xe5\xbe\xb7\xe9\x87\x8c',
         '\xe9\xa6\xac\xe5\xbe\xb7\xe9\x87\x8c\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8d\x80',
         'Espa\xc3\xb1a', '\xe8\xa5\xbf\xe7\x8f\xad\xe7\x89\x99',
         'Espa\xc3\xb1a,Madrid', 'MADRID', 'Espa\xc5\x84a',
         'Madrid capital', 'Spain', 'Communaut\xc3\xa9 de Madrid',
         'Madrid \nMadrid', 'Madrid Espa\xc3\xb1a', 'Madrid, Spain',
         'Autonome Gemeinschaft Madrid', 'Usera', ' ', '  ', '28','Comunidad de Madrid','']

for i in range(0, len(state)-1):
    listing.loc[(listing.state == state[i]), ['state']] = 'Madrid'

# %%
listing.state.unique()
# Out:
# array(['Madrid', nan, 'Salerno Fisciano', 'Valencian Community',
#        'Alicante', 'La Habana', 'Barcelona'], dtype=object)

# %%
listing.state.value_counts()
# Out:
# Madrid                 13287
# Salerno Fisciano           1
# Barcelona                  1
# La Habana                  1
# Alicante                   1
# Valencian Community        1
# Name: state, dtype: int64

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">En las celdas anteriores verificamos que hay que hacer una labor de limpieza con los datos de las variables que se relacionan con la ciudad de Madrid y deshacernos de los registros que no pertenecen a la capital.<br><br></span></div>

# %%
listing = listing[listing.state == 'Madrid']
listing = listing[listing.country == 'Spain']
listing.shape
# Out:
# (13287, 63)

# %%
#Limpieza de neighbourhood_group_cleansed
listing.loc[(listing['neighbourhood_group_cleansed'] == 'Tetu\xc3\xa1n'), ['neighbourhood_group_cleansed']] = 'Tetuan'
listing.loc[(listing['neighbourhood_group_cleansed'] == 'Chamart\xc3\xadn'), ['neighbourhood_group_cleansed']] = 'Chamartin'
listing.loc[(listing['neighbourhood_group_cleansed'] == 'Chamber\xc3\xad'), ['neighbourhood_group_cleansed']] = 'Chamberi'
listing.loc[(listing['neighbourhood_group_cleansed'] == 'Vic\xc3\xa1lvaro'), ['neighbourhood_group_cleansed']] = 'Vicalvario'

# %%
listing.neighbourhood_group_cleansed.value_counts()
# Out:
# Centro                   6754
# Chamberi                  958
# Salamanca                 882
# Arganzuela                788
# Tetuan                    463
# Moncloa - Aravaca         445
# Retiro                    438
# Latina                    379
# Chamartin                 360
# Carabanchel               357
# Ciudad Lineal             309
# Puente de Vallecas        222
# Hortaleza                 185
# Fuencarral - El Pardo     169
# Usera                     144
# San Blas - Canillejas     117
# Villaverde                 83
# Barajas                    80
# Moratalaz                  74
# Villa de Vallecas          46
# Vicalvario                 34
# Name: neighbourhood_group_cleansed, dtype: int64

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Nos vamos dando cuenta de los barrios con más opciones de alquiler en AirBnB.<br><br></span></div>

# %%
col_to_delete = ['host_location', 'neighbourhood', 'country','street', 'smart_location','market', 'city', 'state', 'neighbourhood_cleansed']

# %%
for i in range(0,len(col_to_delete)):
    listing.drop(col_to_delete[i], axis=1, inplace=True)

listing.shape
# Out:
# (13287, 54)

# %%
listing.isnull().sum(axis=0)
# Out:
# id                                     0
# name                                   0
# host_id                                0
# host_name                              3
# host_since                             3
# host_is_superhost                      3
# host_listings_count                    3
# host_total_listings_count              3
# host_verifications                     0
# host_has_profile_pic                   3
# host_identity_verified                 3
# neighbourhood_group_cleansed           0
# zipcode                              439
# latitude                               0
# longitude                              0
# property_type                          0
# room_type                              0
# accommodates                           0
# bathrooms                             49
# bedrooms                              23
# beds                                  49
# bed_type                               0
# amenities                              0
# price                                  0
# weekly_price                        9789
# monthly_price                       9975
# security_deposit                    7581
# cleaning_fee                        5464
# guests_included                        0
# extra_people                           0
# minimum_nights                         0
# maximum_nights                         0
# calendar_updated                       0
# availability_30                        0
# availability_60                        0
# availability_90                        0
# availability_365                       0
# number_of_reviews                      0
# first_review                        2781
# last_review                         2782
# review_scores_rating                2906
# review_scores_accuracy              2924
# review_scores_cleanliness           2918
# review_scores_checkin               2934
# review_scores_communication         2918
# review_scores_location              2936
# review_scores_value                 2936
# requires_license                       0
# instant_bookable                       0
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# calculated_host_listings_count         0
# reviews_per_month                   2781
# dtype: int64

# %% [markdown]
# <br><div style="text-align: left;">
#     <span style="font-weight: bold; color:#FF7674; font-family: 'Courier New'; font-size: 2em;">¿Existen outliers en mi dataset? ¿Qué precio y características tienen los pisos más costosos de mi conjunto de datos?</span>
# </div>
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Sería interesante conocer qué precios tienen los pisos más costosos de mi dataset y qué carácteristicas tienen.<br><br></span>
# </div>

# %%
outliers = listing[listing['price'] >= 1000]
outliers['price'].value_counts()
# Out:
# 1000.0    3
# 3000.0    2
# 3189.0    1
# 7700.0    1
# 1890.0    1
# 1200.0    1
# Name: price, dtype: int64

# %%
outliers.sort_values('price')
# Out:
#              id                                               name    host_id  \
# 10667  16199273                 Private Room in Rios Rosas, Madrid  102392514
# 5814   10715621                  Lujoso apartamento en Gran Vìa 48    3256859
# 957    10495669                  Ático centrico y tranquilo / Atic   46129526
# 2246   14574259  LONGTERM welcome-New,Central,100m² for 1-6 Per...   90311483
# 8855    6681279                Fantastico Piso Barrio de Salamanca   34972297
# 7993     361488                RETIRO PARK2 CHALET INDUSTRIAL-CHIC    1732442
# 8002    1727101                RETIRO PARK1 CHALET INDUSTRIAL-CHIC    1732442
# 8027    2744574                          Mansion with royal garden    9631554
# 10828   1250842                Habitación Moncloa-AravacaArgüelles    6815584
#
#          host_name  host_since host_is_superhost  host_listings_count  \
# 10667       Hemant  2016-11-03                 f                  1.0
# 5814    Fer & Fran  2012-08-14                 f                 14.0
# 957          Elisa  2015-10-09                 f                  1.0
# 2246        Tobias  2016-08-16                 f                  1.0
# 8855   Juan Andres  2015-06-04                 f                  1.0
# 7993         Anouk  2012-02-10                 f                 12.0
# 8002         Anouk  2012-02-10                 f                 12.0
# 8027           K&S  2013-10-25                 t                  1.0
# 10828       Héctor  2013-06-09                 f                  1.0
#
#        host_total_listings_count                         host_verifications  \
# 10667                        1.0                         ['email', 'phone']
# 5814                        14.0     ['email', 'phone', 'reviews', 'jumio']
# 957                          1.0  ['email', 'phone', 'facebook', 'reviews']
# 2246                         1.0              ['email', 'phone', 'reviews']
# 8855                         1.0                         ['email', 'phone']
# 7993                        12.0     ['email', 'phone', 'reviews', 'jumio']
# 8002                        12.0     ['email', 'phone', 'reviews', 'jumio']
# 8027                         1.0     ['email', 'phone', 'reviews', 'jumio']
# 10828                        1.0                                         []
#
#       host_has_profile_pic host_identity_verified  \
# 10667                    t                      f
# 5814                     t                      t
# 957                      t                      f
# 2246                     t                      f
# 8855                     t                      f
# 7993                     t                      t
# 8002                     t                      t
# 8027                     t                      t
# 10828                    t                      f
#
#       neighbourhood_group_cleansed zipcode   latitude  longitude  \
# 10667                     Chamberi   28003  40.441251  -3.697699
# 5814                        Centro   28013  40.421617  -3.705310
# 957                         Centro   28013  40.421374  -3.710629
# 2246                        Centro   28005  40.409006  -3.710069
# 8855                     Salamanca   28006  40.434467  -3.682262
# 7993                        Retiro   28007  40.409084  -3.673131
# 8002                        Retiro   28007  40.410194  -3.671795
# 8027                     Salamanca       -  40.423505  -3.689261
# 10828            Moncloa - Aravaca   28008  40.430939  -3.721799
#
#       property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 10667     Apartment     Private room             1        1.0       1.0   1.0
# 5814      Apartment  Entire home/apt             4        1.0       1.0   1.0
# 957       Apartment  Entire home/apt             4        1.0       1.0   2.0
# 2246      Apartment  Entire home/apt             6        2.0       2.0   2.0
# 8855    Condominium  Entire home/apt             4        2.0       2.0   2.0
# 7993         Chalet  Entire home/apt             6        3.0       3.0   3.0
# 8002          House  Entire home/apt             6        3.0       3.0   3.0
# 8027          House  Entire home/apt            10        6.0       4.0   9.0
# 10828     Apartment     Private room             5        NaN       1.0   NaN
#
#        bed_type                                          amenities   price  \
# 10667  Real Bed  {TV,"Wireless Internet",Kitchen,Heating,"Famil...  1000.0
# 5814   Real Bed  {TV,"Wireless Internet","Air conditioning","Wh...  1000.0
# 957    Real Bed  {TV,Internet,"Wireless Internet","Air conditio...  1000.0
# 2246   Real Bed  {TV,Internet,"Wireless Internet","Air conditio...  1200.0
# 8855   Real Bed  {TV,"Air conditioning",Kitchen,Doorman,"Elevat...  1890.0
# 7993   Real Bed  {"Wireless Internet",Kitchen,"Free parking on ...  3000.0
# 8002   Real Bed  {"Wireless Internet",Kitchen,"Free parking on ...  3000.0
# 8027   Real Bed                                                 {}  3189.0
# 10828  Real Bed                                                 {}  7700.0
#
#        weekly_price  monthly_price security_deposit  cleaning_fee  \
# 10667           NaN            NaN          $100.00          15.0
# 5814            NaN            NaN              NaN           NaN
# 957             NaN            NaN              NaN          20.0
# 2246            NaN            NaN          $500.00          50.0
# 8855         1843.0         1843.0              NaN           NaN
# 7993          910.0         2910.0        $3,000.00         100.0
# 8002          910.0         2910.0        $3,000.00         100.0
# 8027            NaN            NaN              NaN           NaN
# 10828           NaN            NaN              NaN           NaN
#
#        guests_included  extra_people  minimum_nights  maximum_nights  \
# 10667                1           5.0               1              15
# 5814                 2          15.0               2            1125
# 957                  2           5.0               1            1125
# 2246                 1           0.0               3            1125
# 8855                 1           0.0               1            1125
# 7993                 1         250.0               5             365
# 8002                 1         250.0               5            1125
# 8027                 1           0.0               1            1125
# 10828                1           0.0               1            1125
#
#       calendar_updated  availability_30  availability_60  availability_90  \
# 10667     4 months ago               29               59               89
# 5814         yesterday                6               34               64
# 957       7 months ago               29               49               79
# 2246      2 months ago                0                0                0
# 8855      8 months ago                0                0                0
# 7993      2 months ago                0                0                0
# 8002      2 months ago                0                0                0
# 8027       5 weeks ago               30               60               90
# 10828     7 months ago               29               59               89
#
#        availability_365  number_of_reviews first_review last_review  \
# 10667               364                  0          NaN         NaN
# 5814                160                  4   2016-02-24  2016-08-03
# 957                 354                 42   2016-01-14  2016-09-13
# 2246                189                  2   2016-08-27  2017-01-03
# 8855                  0                  0          NaN         NaN
# 7993                  0                  0          NaN         NaN
# 8002                  0                  0          NaN         NaN
# 8027                365                  0          NaN         NaN
# 10828               364                  0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 10667                   NaN                     NaN
# 5814                   80.0                     9.0
# 957                    91.0                    10.0
# 2246                  100.0                    10.0
# 8855                    NaN                     NaN
# 7993                    NaN                     NaN
# 8002                    NaN                     NaN
# 8027                    NaN                     NaN
# 10828                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 10667                        NaN                    NaN
# 5814                         9.0                    7.0
# 957                          9.0                    9.0
# 2246                         9.0                   10.0
# 8855                         NaN                    NaN
# 7993                         NaN                    NaN
# 8002                         NaN                    NaN
# 8027                         NaN                    NaN
# 10828                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 10667                          NaN                     NaN
# 5814                           6.0                     8.0
# 957                            9.0                    10.0
# 2246                          10.0                    10.0
# 8855                           NaN                     NaN
# 7993                           NaN                     NaN
# 8002                           NaN                     NaN
# 8027                           NaN                     NaN
# 10828                          NaN                     NaN
#
#        review_scores_value requires_license instant_bookable  \
# 10667                  NaN                t                f
# 5814                   9.0                t                t
# 957                    9.0                t                t
# 2246                  10.0                t                f
# 8855                   NaN                t                f
# 7993                   NaN                t                f
# 8002                   NaN                t                f
# 8027                   NaN                t                f
# 10828                  NaN                t                t
#
#       cancellation_policy require_guest_profile_picture  \
# 10667            moderate                             f
# 5814               strict                             f
# 957              flexible                             f
# 2246             flexible                             f
# 8855               strict                             f
# 7993               strict                             f
# 8002             flexible                             f
# 8027             flexible                             f
# 10828            flexible                             f
#
#       require_guest_phone_verification  calculated_host_listings_count  \
# 10667                                f                               1
# 5814                                 f                               8
# 957                                  f                               1
# 2246                                 f                               1
# 8855                                 f                               1
# 7993                                 f                              12
# 8002                                 f                              12
# 8027                                 f                               1
# 10828                                f                               1
#
#        reviews_per_month
# 10667                NaN
# 5814                0.29
# 957                 2.79
# 2246                0.27
# 8855                 NaN
# 7993                 NaN
# 8002                 NaN
# 8027                 NaN
# 10828                NaN

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Podemos sacar varias conclusiones:<br> <br>
#     - 1) Existe un alquiler de 7700 Euros por noche, por una habitación! A menos que sea una habitación del Palacio Real, no lo creo muy real. Eliminamos este regitro (id=1250842)<br>
#     - 2) Existe otro registro, que es una habitación de alquiler por 1000 euros la noche. Parece no tener mucho sentido. (id=16199273)<br>
#     - 3) Existen pisos que en el campo 'number_of_reviews' tienen cero comentarios. Esto indica que nunca han sido alquilados. Tomando en consideración el precio, pueden ser considerados como outliers. Eliminar.<br></span>
# </div>

# %%
id_to_delete = [6681279, 361488, 1727101, 2744574, 1250842, 16199273]
for i in range(0,len(id_to_delete)):
    listing = listing[listing['id'] != id_to_delete[i] ]

# %%
#outliers.dropna(subset=['reviews_per_month'])

# %% [markdown]
# <br><br><div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Tenemos otra serie de datos (que aún no sé si utilizaré pero pueden servirme a futuro) que deben ser cambiados a su formato correcto. Es el caso de variables con fechas y variables booleanas, que se tratan a continuación:</span>
# </div>

# %%
# Cambiamos el formato a booleano
bools = ['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'requires_license', 'instant_bookable', 
         'require_guest_profile_picture', 'require_guest_phone_verification']
for i in bools:
    listing[i] = listing[i].map({'t': True, 'f': False})

# %%
# Cambiamos el formato de las fechas
fechas = ['host_since', 'first_review', 'last_review']
for i in fechas:
    listing[i] = pd.to_datetime(listing[i], infer_datetime_format=True)

# %%
listing.head(3)
# Out:
#             id                                 name   host_id       host_name  \
# 9135   1690312  Apartamento 200m2 para 5/6 personas   8815003           Maite
# 441    4678105   Central sunny apartment with views  17705919  Barbara Y Javi
# 5021  13091807  long rental study old town madrid 2  21137168             Ale
#
#      host_since host_is_superhost  host_listings_count  \
# 9135 2013-09-13             False                  2.0
# 441  2014-07-06             False                  1.0
# 5021 2014-09-09             False                  4.0
#
#       host_total_listings_count                      host_verifications  \
# 9135                        2.0  ['email', 'phone', 'reviews', 'jumio']
# 441                         1.0  ['email', 'phone', 'reviews', 'jumio']
# 5021                        4.0           ['email', 'phone', 'reviews']
#
#      host_has_profile_pic host_identity_verified neighbourhood_group_cleansed  \
# 9135                 True                   True                    Chamartin
# 441                  True                   True                       Centro
# 5021                 True                  False                       Centro
#
#      zipcode   latitude  longitude property_type        room_type  \
# 9135   28016  40.456181  -3.676956     Apartment  Entire home/apt
# 441    28005  40.412441  -3.711110     Apartment  Entire home/apt
# 5021   28004  40.426694  -3.707727     Apartment     Private room
#
#       accommodates  bathrooms  bedrooms  beds  bed_type  \
# 9135             6        2.0       3.0   3.0  Real Bed
# 441              2        1.0       2.0   2.0  Real Bed
# 5021             2        1.0       2.0   1.0  Real Bed
#
#                                               amenities  price  weekly_price  \
# 9135  {TV,"Cable TV",Internet,"Wireless Internet",Ki...  200.0           NaN
# 441   {TV,Internet,"Wireless Internet",Kitchen,"Elev...  100.0           NaN
# 5021  {Internet,"Wireless Internet","Air conditionin...   39.0           NaN
#
#       monthly_price security_deposit  cleaning_fee  guests_included  \
# 9135            NaN          $500.00           NaN                1
# 441             NaN          $150.00          10.0                1
# 5021            NaN              NaN           NaN                1
#
#       extra_people  minimum_nights  maximum_nights calendar_updated  \
# 9135          50.0               2               7      2 weeks ago
# 441            0.0               2            1125      2 weeks ago
# 5021           0.0               7             365            today
#
#       availability_30  availability_60  availability_90  availability_365  \
# 9135               30               60               90               365
# 441                 0                6               36               311
# 5021                7                9               29               281
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 9135                  1   2015-05-24  2015-05-24                  80.0
# 441                  20   2015-02-01  2016-10-04                  94.0
# 5021                  2   2017-03-07  2017-03-20                  80.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 9135                     8.0                       10.0
# 441                      9.0                        9.0
# 5021                    10.0                        9.0
#
#       review_scores_checkin  review_scores_communication  \
# 9135                   10.0                          8.0
# 441                    10.0                         10.0
# 5021                   10.0                          9.0
#
#       review_scores_location  review_scores_value requires_license  \
# 9135                    10.0                  8.0             True
# 441                     10.0                  9.0             True
# 5021                    10.0                 10.0             True
#
#      instant_bookable cancellation_policy require_guest_profile_picture  \
# 9135            False            flexible                         False
# 441             False            flexible                         False
# 5021             True              strict                         False
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 9135                            False                               2
# 441                             False                               1
# 5021                            False                               4
#
#       reviews_per_month
# 9135               0.04
# 441                0.75
# 5021               1.82

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">Generamos el nuevo fichero con la data limpia</span>
# </div>

# %%
listing.to_csv('./listing_clean.csv', sep=',')

# %% [markdown]
# <div style="text-align: left;"><br><br><br>
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">De momento hemos limpiado los datos del dataset Listing...<br><br>Seguimos...<br><br></span>
# </div>

# %% [markdown]
# <br><div style="text-align: left;">
#     <span style="font-weight: bold; color:#FF7674; font-family: 'Courier New'; font-size: 2em;">Dataset "Calendar":</span>
# </div>
#
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">
# Vamos ahora a trabajar con el dataset Calendar. Este dataset es importante para conocer por ejemplo, la disponibilidad de pisos durante un año, entre otras cosas interesantes.</span>
# </div>

# %%
calendar.head()
# Out:
#    listing_id        date available   price
# 0     7830063  2018-01-03         t  $42.00
# 1     7830063  2018-01-02         t  $42.00
# 2     7830063  2018-01-01         t  $42.00
# 3     7830063  2017-12-31         f     NaN
# 4     7830063  2017-12-30         f     NaN

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">
# Revisamos los data types de las columnas para saber si son del tipo correcto</span>
# </div>

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4867275 entries, 0 to 4867274
# Data columns (total 4 columns):
# listing_id    int64
# date          object
# available     object
# price         object
# dtypes: int64(1), object(3)
# memory usage: 148.5+ MB

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">
# EL dataset calendar contiene data de los precios para cada piso en alquiler para todo un año y con información de la disponibilidad de los mismos.
# <br><br>
# Al igual que el dataset anterior, revisamos que los tipos de datos sean los correctos y, si no lo son, convertirlos.
# <br><br>
# Nos damos cuenta de que la columna "date", "available" y "price" no tienen el formato que deberían.
# Date debe ser convertido al formato datetime, "price" al igual que el dataset anterior debe cambiarse a float, eliminando previamente el símbolo de dólar y eliminando el punto de separador de miles; y finalmente "available" debe ser una variable boolean.
# </span>
# </div>

# %%
# Cambiamos el formato de las fechas
calendar['date'] = pd.to_datetime(calendar.date, infer_datetime_format=True)
calendar['date'].head(3)
# Out:
# 0   2018-01-03
# 1   2018-01-02
# 2   2018-01-01
# Name: date, dtype: datetime64[ns]

# %%
# Quitamos el signo de dólar y cualquier separador de miles donde el precio no sea NA
calendar['price'] = calendar.loc[calendar.price.notnull()].price.apply(lambda x: re.sub('[$,]', '', x))

# %%
# Price se cambia a numérico
calendar['price'] = pd.to_numeric(calendar.price)
calendar['price'].head(3)
# Out:
# 0    42.0
# 1    42.0
# 2    42.0
# Name: price, dtype: float64

# %%
# La columna 'available' se convierte en boolean
calendar['available'] = calendar['available'].map({'t': True, 'f': False})
calendar['available'].head(3)
# Out:
# 0    True
# 1    True
# 2    True
# Name: available, dtype: bool

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4867275 entries, 0 to 4867274
# Data columns (total 4 columns):
# listing_id    int64
# date          datetime64[ns]
# available     bool
# price         float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1)
# memory usage: 116.0 MB

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">
# Hacemos un chequeo típico de la data para verificar anormalidades o cualquier cosa que nos parezca extraña.
# <br><br>
# Vamos a generar una pequeña tabla con los valores mínimos y máximos y los missing values para la columna "date" y "price"
# </span>
# </div>

# %%
# Get min, max and number of missing values for Date and Price
min_date = calendar.date.min()
max_date = calendar.date.max()
num_list = len(calendar.listing_id.unique())
price_missing = len(calendar.loc[pd.isnull(calendar.price)])
date_missing = len(calendar.loc[pd.isnull(calendar.date)])
min_price = calendar.price.min()
max_price = calendar.price.max()

lista = [['Precio', min_price, max_price, price_missing], ['Fecha', min_date, max_date, date_missing]]
cols = ['Column','Min','Max','Missing']

data = pd.DataFrame(lista, columns=cols)
data
# Out:
#    Column                  Min                  Max  Missing
# 0  Precio                    9                15505  2121828
# 1   Fecha  2017-04-07 00:00:00  2018-04-07 00:00:00        0

# %%
len(calendar)
# Out:
# 4867275

# %% [markdown]
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">
# El precio parece ser muy diferente entre los apartamentos, desde 9.00 dólares por noche a 15.505.00 por noche. Recordemos que no hemos separado los pisos entre los 3 tipos de habitaciones diponibles (habitación completa, habitación compartida y piso completo) lo que podría explicar el por qué estos valores máximos y mínimos.<br><br>
# Vemos también que el dataset tiene datos de un año, desde la fecha que se extrajo la data hasta un año siguiente. Nos está mostrando el calendario de reservas para un año desde el 04/07/2017.
# <br><br>
# Es de notar la cifra en la tabla en cuanto a datos missing de precio. Son 2121828 datos missing, que forman casi el 50% de los datos calendario completo.
# <br><br>
# Los datos faltantes en este dataset, representan cuando se ha reservado un piso.
# Que un dato NA sea considerado como un piso reservado tiene lógica ya que es probable que el dato no haya podido ser extraído al momento de hacer scrapping, ya que estaba reservado. <br><br>
# Convertimos este nuevo dataset limpio, a un fichero .csv
# </span>
# </div>

# %%
calendar.to_csv('./calendar_clean.csv', sep=',')

# %% [markdown]
# <br><div style="text-align: left;">
#     <span style="font-weight: bold; color:#FF7674; font-family: 'Courier New'; font-size: 2em;">Dataset "Review":</span>
# </div>
#
# <div style="text-align: left;">
#     <span style="color:#2467C0; font-family: 'Courier New'; font-size: 1.5em;">
# Finalmente tenemos el dataset "Review" el cuál trabajaremos para tratar de sacar información de dicho DataSet.</span>
# </div>

# %%
review.head(3)
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0    15128601  103956852  2016-09-25     48832799        Amparo
# 1    15128601  105883025  2016-10-03     87158075       Daniela
# 2    15128601  106595943  2016-10-07     10102108        Fabien
#
#                                             comments
# 0  Apartamento muy acogedor, limpio y cómodo, en ...
# 1  La descripción del anuncio era correcta, las f...
# 2  Nice and cosy place. Really peaceful and quiet...

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306870 entries, 0 to 306869
# Data columns (total 6 columns):
# listing_id       306870 non-null int64
# id               306870 non-null int64
# date             306870 non-null object
# reviewer_id      306870 non-null int64
# reviewer_name    306870 non-null object
# comments         306641 non-null object
# dtypes: int64(3), object(3)
# memory usage: 14.0+ MB

# %%
# Cambiamos el formato de las fechas
review['date'] = pd.to_datetime(review.date, infer_datetime_format=True)
review['date'].head(3)
# Out:
# 0   2016-09-25
# 1   2016-10-03
# 2   2016-10-07
# Name: date, dtype: datetime64[ns]

# %%
review.to_csv('./review_clean.csv', sep=',')
